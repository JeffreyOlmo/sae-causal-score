# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]= "5,6,7"
import torch
from tqdm import tqdm
import plotly.express as px

torch.set_grad_enabled(False);

# %%
from transformer_lens import HookedTransformer
from sae_lens import SAE

# Choose a layer you want to focus on
device= "cuda:0"
model = HookedTransformer.from_pretrained("gpt2-small").to('cuda')

# Initialize SAE
layer = 8
sae, cfg_dict, _ = SAE.from_pretrained(
    release="gpt2-small-res-jb",
    sae_id=f"blocks.{layer}.hook_resid_pre",
    device= "cuda:0"
)

# get hook point
hook_point = sae.cfg.hook_name
print(hook_point)
# Out:
# Loaded pretrained model gpt2-small into HookedTransformer
# Moving model to device:  cuda
# blocks.8.hook_resid_pre

# %%
from sae_lens import SAETrainingRunner, LanguageModelSAERunnerConfig, SAE
from sae_lens.training.training_sae import TrainingSAE
import torch
from typing import Any, Tuple, cast
from transformer_lens import HookedTransformer
from typing import Optional
from datasets import Dataset, IterableDataset
from datasets import load_dataset
import os
import torch.nn.functional as F
import wandb

class RSAETrainingRunner(SAETrainingRunner):
    def __init__(
        self,
        cfg: LanguageModelSAERunnerConfig,
        r_weight: float = 1,
        n_steps: int = 50,
        k: int = 5,
    ):
        super().__init__(cfg)
        self.r_weight = r_weight
        self.n_steps = n_steps
        self.k = k
        self.tokens_processed = 0
        self.dataset_iterator: Optional[Iterator] = None
        self.dataset: Optional[Dataset | IterableDataset] = None
        self.optimizer = torch.optim.Adam(self.sae.parameters(), lr=self.cfg.lr)
        self.step = 0

    def run(self):
        if self.cfg.log_to_wandb:
            wandb.init(
                project=self.cfg.wandb_project,
                config=cast(Any, self.cfg),
                name=self.cfg.run_name,
                id=self.cfg.wandb_id,
            )

        self._compile_if_needed()

        try:
            # Main training loop
            while self.tokens_processed < self.cfg.training_tokens:
                batch = self.get_next_batch()
                loss_dict = self.training_step(batch)
                
                # Update tokens processed
                self.tokens_processed += batch.numel()
                
                # Log metrics
                if self.cfg.log_to_wandb and self.step % self.cfg.wandb_log_frequency == 0:
                    wandb.log({**loss_dict, "tokens_processed": self.tokens_processed}, step=self.step)

                self.step += 1

        except KeyboardInterrupt:
            print("Training interrupted. Saving checkpoint...")
            self.save_checkpoint(self.step)

        if self.cfg.log_to_wandb:
            wandb.finish()

        return self.sae

    def setup_dataset(self):
        if self.cfg.is_dataset_tokenized:
            self.dataset = load_dataset(self.cfg.dataset_path, streaming=self.cfg.streaming, split="train")
        else:
            # If the dataset is not tokenized, we need to tokenize it
            raw_dataset = load_dataset(self.cfg.dataset_path, streaming=self.cfg.streaming, split="train")
            self.dataset = raw_dataset.map(lambda examples: self.model.tokenizer(examples['text'], truncation=True, padding='max_length', max_length=self.cfg.context_size), batched=True)
        
        self.dataset_iterator = iter(self.dataset)

    def check_weight_updates(self):
        if not hasattr(self, 'old_weights'):
            self.old_weights = {name: param.clone().detach() for name, param in self.sae.named_parameters()}
            return

        total_diff = 0
        max_diff = 0
        for name, param in self.sae.named_parameters():
            diff = (param.data - self.old_weights[name]).abs().sum().item()
            total_diff += diff
            max_diff = max(max_diff, diff)
            self.old_weights[name] = param.clone().detach()
        
        print(f"Total weight diff: {total_diff:.6f}, Max weight diff: {max_diff:.6f}")
        #wandb.log({"total_weight_diff": total_diff, "max_weight_diff": max_diff}, step=self.step)

    def get_next_batch(self) -> torch.Tensor:
        if self.dataset_iterator is None:
            self.setup_dataset()
        
        batch_size = self.cfg.train_batch_size_tokens // self.cfg.context_size
        batch = []

        while len(batch) < batch_size:
            try:
                item = next(self.dataset_iterator)
                if self.cfg.is_dataset_tokenized:
                    input_ids = torch.tensor(item['input_ids'], dtype=torch.long)
                else:
                    input_ids = torch.tensor(item['input_ids'], dtype=torch.long)
                
                # Ensure the sequence is the correct length
                if input_ids.size(0) < self.cfg.context_size:
                    input_ids = torch.cat([input_ids, torch.zeros(self.cfg.context_size - input_ids.size(0), dtype=torch.long)])
                elif input_ids.size(0) > self.cfg.context_size:
                    input_ids = input_ids[:self.cfg.context_size]
                
                batch.append(input_ids)

            except StopIteration:
                # If we've reached the end of the dataset, reset the iterator
                self.dataset_iterator = iter(self.dataset)
                # If we couldn't fill the batch, break and return what we have
                if len(batch) > 0:
                    break
                else:
                    continue  # If the batch is empty, try again with the reset iterator

        # Stack the batch items into a single tensor
        batch_tensor = torch.stack(batch)

        return batch_tensor.to(self.cfg.device)

    def training_step(self, input_ids: torch.Tensor) -> dict[str, float]:
        # Compute activations and integrated gradients
        activations, attributions = self.integrated_gradients(
            self.model,
            input_ids,
            self.cfg.hook_name,
            self.n_steps,
            largest_logit=False
        )

        with torch.enable_grad():
            # Compute R score for each token in the sequence
            r_scores = []
            for i in range(activations.shape[1]): 
                 # Iterate over sequence length
                r_score = self.compute_r_score(
                    self.sae,
                    activations[:, i],
                    attributions[:, i],
                    self.k
                )
            
                r_scores.append(r_score)
            
            if i % 5 == 0:
                self.check_weight_updates()
            avg_r_score = sum(r_scores) / len(r_scores)
            sae_output = self.sae.training_forward_pass(activations, self.cfg.l1_coefficient)
            r_loss = 1 - avg_r_score
            print(f"mse and l0 loss: {sae_output.loss}")
            print(f"R_loss: {r_loss}")
            print(f"Average R_score: {avg_r_score}")
            total_loss = r_loss + (sae_output.loss / 800000)

        # Perform optimization step
        self.optimizer.zero_grad()
        total_loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.sae.parameters(), max_norm=float('inf'))
        print(f"gradient_norm: {grad_norm}")
        #wandb.log({"gradient_norm": grad_norm}, step=self.step)
        self.optimizer.step()

        # Create a dictionary for logging
        loss_dict = {
            'mse_loss': sae_output.mse_loss,
            'l1_loss': sae_output.l1_loss,
            'ghost_grad_loss': sae_output.ghost_grad_loss,
            'auxiliary_reconstruction_loss': sae_output.auxiliary_reconstruction_loss,
            'r_score': avg_r_score,
            'total_loss': total_loss.item()
        }
        return loss_dict


    def compute_r_score(
        self,
        sae: SAE,
        activation: torch.Tensor,
        attribution: torch.Tensor,
        k: int = 5
    ) -> torch.Tensor:
        """
        Compute the R-score for multiple sets of vectors and attributions.
        
        Args:
        sae_directions: Tensor of shape [batch_size, num_vectors, vector_dim]
        attribution: Tensor of shape [batch_size, vector_dim]
        top_k_values: Tensor of shape [batch_size, num_vectors]
        epsilon: Small value to avoid division by zero
        
        Returns:
        r_scores: Tensor of shape [batch_size]
        """
        epsilon: float = 1e-8
        sae_directions, top_k_values = self.get_top_k_active_directions(sae, activation, k)
        sae_directions = sae_directions.permute(2, 1, 0)

        #print(f"attribtion: {attribution.shape}")
        #print(f"sae_directions: {sae_directions.shape}")

        # Compute the projection matrix
        V = sae_directions.transpose(1, 2)  # [batch_size, vector_dim, num_vectors]
        VTV = torch.bmm(V.transpose(1, 2), V)  # [batch_size, num_vectors, num_vectors]
        VTV_inv = torch.inverse(VTV + epsilon * torch.eye(VTV.size(1), device=VTV.device).unsqueeze(0))
        P = torch.bmm(torch.bmm(V, VTV_inv), V.transpose(1, 2))  # [batch_size, vector_dim, vector_dim]
        
        # Compute the projection of attribution onto the span of weighted directions
        u = attribution.unsqueeze(-1)  # [batch_size, vector_dim, 1]
        proj_u = torch.bmm(P, u)  # [batch_size, vector_dim, 1]
        
        
        # Compute the R-score
        r_scores = torch.sqrt(
            (torch.bmm(u.transpose(1, 2), proj_u).squeeze(-1) + epsilon) /
            (torch.sum(u**2, dim=1) + epsilon)
        ).squeeze(-1)
        #print(f"r_scores {r_scores}")
        return r_scores.mean()

    def integrated_gradients(
        self,
        model: HookedTransformer,
        input_ids: torch.Tensor,
        target_layer: str,
        n_steps: int = 30,
        largest_logit: bool = False,
    ) -> Tuple[torch.Tensor, torch.Tensor]:
        device = input_ids.device
        layer_index = int(target_layer.split('.')[1])

        # Get baseline and input activations
        with torch.no_grad():
            _, cache = model.run_with_cache(input_ids)
            input_activation = cache[target_layer]
        
        baseline_activation = torch.zeros_like(input_activation)
        delta = (input_activation - baseline_activation) / n_steps
        integrated_gradients = torch.zeros_like(input_activation)

        for i in range(n_steps + 1):
            with torch.enable_grad():
                with torch.autograd.set_detect_anomaly(True):
                    interpolated_activation = baseline_activation + i * delta
                    interpolated_activation.requires_grad_(True)
                    logits = self.compute_subsequent_outputs_logits_only(model, interpolated_activation, layer_index)

                    if largest_logit:
                        last_token_logits = logits[:, -1]
                        max_logit_value, max_logit_index = torch.max(last_token_logits, dim=-1)
                        
                        # Compute gradient only for the highest logit
                        max_logit_value.sum().backward(retain_graph=True)
                        gradient = interpolated_activation.grad

                        integrated_gradients += gradient / n_steps
                        interpolated_activation.grad = None  
                    else:
                        loss = logits[:, -1, input_ids[:, -1]].sum()
                        loss.backward(create_graph=False)
                        gradient = interpolated_activation.grad

                        integrated_gradients += gradient / n_steps

        attributions = integrated_gradients * (input_activation - baseline_activation)
        return input_activation, attributions

    
    def get_top_k_active_directions(self, sae: SAE, activation: torch.Tensor, k: int):
        # Assuming activation shape is [16, 768]
        latent = sae.encode(activation)  # [16, n_features]
        top_k_values, top_k_indices = torch.topk(latent.abs(), k, dim=-1)  # Both: [16, 5]
        
        # Gather top k directions for each item in the batch
        top_k_directions = sae.W_enc[:, top_k_indices.flatten()].view(sae.W_enc.shape[0], k, -1)  # [768, 5, 16]
        
        return top_k_directions, top_k_values

    def compute_subsequent_outputs_logits_only(self, model: torch.nn.Module, activation: torch.Tensor, layer_index: int) -> torch.Tensor:
        # Ensure activation requires gradients
        with torch.enable_grad():
            if not activation.requires_grad:
                activation.requires_grad_(True)
            if activation.ndim == 2:
                activation = activation.unsqueeze(1)       
            current_activation = activation
            for block in model.blocks[layer_index+1:]:
                current_activation = block(current_activation)
                
            current_activation = model.ln_final(current_activation)
            logits = model.unembed(current_activation)
        return logits
    



cfg = LanguageModelSAERunnerConfig(
    # Model and SAE Configuration
    model_name="gpt2-small",
    hook_name="blocks.8.hook_resid_pre",
    hook_layer=8,
    d_in=768,
    expansion_factor=32,

    # Dataset Configuration
    dataset_path="apollo-research/Skylion007-openwebtext-tokenizer-gpt2",
    is_dataset_tokenized=True,
    streaming=True,

    # Training Parameters
    train_batch_size_tokens=400,
    context_size=256,
    training_tokens=10_000_000,  # 10 million tokens for finetuning
    lr=5e-3,  # Lower learning rate for finetuning
    lr_scheduler_name="cosine",
    l1_coefficient=5e-3,
    lp_norm=1.0,

    # Logging and Checkpointing
    log_to_wandb=True,
    wandb_project="sae_finetuning_r_score",
    n_checkpoints=5,
    checkpoint_path="./checkpoints",

    # Hardware Configuration
    device="cuda",
    dtype="float32",
)
os.environ["CUDA_VISIBLE_DEVICES"]= "4,5,6,7"
pretrained_sae, original_cfg_dict, sparsity = SAE.from_pretrained(
    release="gpt2-small-res-jb",
    sae_id="blocks.8.hook_resid_pre",
    device="cuda:0",
)
# Initialize the runner with the pretrained SAE
runner = RSAETrainingRunner(cfg, pretrained_sae, n_steps=30, k=5)
# Out:
# Run name: 24576-L1-0.005-LR-0.007-Tokens-1.000e+07
# n_tokens_per_buffer (millions): 0.16384
# Lower bound: n_contexts_per_buffer (millions): 0.00064
# Total training steps: 25000
# Total wandb updates: 2500
# n_tokens_per_feature_sampling_window (millions): 204.8
# n_tokens_per_dead_feature_window (millions): 102.4
# We will reset the sparsity calculation 12 times.
# Number tokens in sparsity calculation window: 8.00e+05
# Loaded pretrained model gpt2-small into HookedTransformer
# Resolving data files:   0%|          | 0/73 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/73 [00:00<?, ?it/s]
# Objective value: 7284788.0000:   2%|▏         | 2/100 [00:00<00:00, 201.97it/s]
# /usr/local/lib/python3.10/dist-packages/sae_lens/training/training_sae.py:455: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   out = torch.tensor(origin, dtype=self.dtype, device=self.device)

# %%
import os
import json
import torch
import wandb
from sae_lens import SAE

def save_finetuned_sae(sae: SAE, config: dict, step: int, save_path: str, log_to_wandb: bool = True):
    # Create the save directory
    checkpoint_path = os.path.join(save_path, f"finetuned_sae_step_{step}")
    os.makedirs(checkpoint_path, exist_ok=True)
    
    # Save the SAE locally
    sae.save_model(checkpoint_path)
    
    # Save the configuration
    config_path = os.path.join(checkpoint_path, "config.json")
    with open(config_path, "w") as f:
        json.dump(config, f)
    
    print(f"Finetuned SAE saved locally to: {checkpoint_path}")
    
    # Log to wandb if enabled
    if log_to_wandb:
        # Initialize wandb if it's not already running
        if wandb.run is None:
            wandb.init(project="ae_finetuning_r_score")
        
        # Create a wandb Artifact
        artifact = wandb.Artifact(
            name=f"finetuned_sae_step_{step}",
            type="model",
            description="Finetuned Sparse Autoencoder",
            metadata=config
        )
        
        # Add files to the artifact
        artifact.add_file(os.path.join(checkpoint_path, "SAE_WEIGHTS_PATH"))
        artifact.add_file(os.path.join(checkpoint_path, "SAE_CFG_PATH"))
        artifact.add_file(config_path)
        
        # Log the artifact to wandb
        wandb.log_artifact(artifact)
        
        print(f"Finetuned SAE logged to wandb as artifact: {artifact.name}")

# %%
import wandb
finetuned_sae = runner.run()

save_finetuned_sae(
    sae=finetuned_sae,
    config=runner.cfg.to_dict(),
    step=runner.step,
    save_path="./checkpoints",
    log_to_wandb=True
)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: jeffreyjolmo (jeffreyjolmo-byu). Use `wandb login --relogin` to force relogin
# wandb version 0.17.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/mnt/pccfs2/backed_up/jeffolmo/sae_functional_significance/wandb/run-20240716_162629-hqiw8ojx</code>
# Syncing run <strong><a href='https://wandb.ai/jeffreyjolmo-byu/sae_finetuning_r_score/runs/hqiw8ojx' target="_blank">24576-L1-0.005-LR-0.007-Tokens-1.000e+07</a></strong> to <a href='https://wandb.ai/jeffreyjolmo-byu/sae_finetuning_r_score' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/jeffreyjolmo-byu/sae_finetuning_r_score' target="_blank">https://wandb.ai/jeffreyjolmo-byu/sae_finetuning_r_score</a>
#  View run at <a href='https://wandb.ai/jeffreyjolmo-byu/sae_finetuning_r_score/runs/hqiw8ojx' target="_blank">https://wandb.ai/jeffreyjolmo-byu/sae_finetuning_r_score/runs/hqiw8ojx</a>
# Resolving data files:   0%|          | 0/73 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/73 [00:00<?, ?it/s]
# mse and l0 loss: 87187.8828125
# R_loss: 0.9266918897628784
# Average R_score: 0.07330808788537979
# gradient_norm: 0.9149163961410522
# Total weight diff: 261963.513319, Max weight diff: 131095.546875
# mse and l0 loss: 25916844.0
# R_loss: 0.9198705554008484
# Average R_score: 0.08012945204973221
# gradient_norm: 61.02265930175781
# Total weight diff: 185910.203157, Max weight diff: 96817.171875
# mse and l0 loss: 540569.375
# R_loss: 0.9219563007354736
# Average R_score: 0.07804370671510696
# gradient_norm: 2.5053188800811768
# Total weight diff: 146006.875874, Max weight diff: 73751.625000
# mse and l0 loss: 1548736.625
# R_loss: 0.9207723736763
# Average R_score: 0.07922764867544174
# gradient_norm: 6.076990127563477
# Total weight diff: 110240.001604, Max weight diff: 60967.070312
# mse and l0 loss: 2297846.5
# R_loss: 0.921838641166687
# Average R_score: 0.07816135883331299
# gradient_norm: 3.3758585453033447
# Total weight diff: 103505.716780, Max weight diff: 52891.246094
# mse and l0 loss: 1291559.375
# R_loss: 0.9197359085083008
# Average R_score: 0.08026406913995743
# gradient_norm: 1.8445560932159424
# Total weight diff: 91151.106794, Max weight diff: 45734.359375
# mse and l0 loss: 663920.125
# R_loss: 0.9224333167076111
# Average R_score: 0.07756666839122772
# gradient_norm: 1.5935028791427612
# Total weight diff: 79060.733567, Max weight diff: 39699.875000
# mse and l0 loss: 1833172.25
# R_loss: 0.9198967218399048
# Average R_score: 0.08010327816009521
# gradient_norm: 2.520313024520874
# Total weight diff: 65385.230280, Max weight diff: 37425.964844
# mse and l0 loss: 5332257.0
# R_loss: 0.9206864833831787
# Average R_score: 0.07931350916624069
# gradient_norm: 6.565404891967773
# Total weight diff: 68747.340276, Max weight diff: 40185.601562
# mse and l0 loss: 10063011.0
# R_loss: 0.9214864373207092
# Average R_score: 0.07851355522871017
# gradient_norm: 10.518139839172363
# Total weight diff: 89966.157149, Max weight diff: 47379.167969
# mse and l0 loss: 4652599.0
# R_loss: 0.918053150177002
# Average R_score: 0.08194684237241745
# gradient_norm: 8.237343788146973
# Total weight diff: 74370.377105, Max weight diff: 38400.484375
# mse and l0 loss: 2841414.0
# R_loss: 0.9088032245635986
# Average R_score: 0.09119679033756256
# gradient_norm: 5.761858940124512
# Total weight diff: 63667.343637, Max weight diff: 34805.804688
# mse and l0 loss: 7779872.0
# R_loss: 0.9224885702133179
# Average R_score: 0.07751140743494034
# gradient_norm: 13.854363441467285
# Total weight diff: 57957.146040, Max weight diff: 34438.632812
# mse and l0 loss: 5854139.0
# R_loss: 0.9196721911430359
# Average R_score: 0.08032781630754471
# gradient_norm: 10.978464126586914
# Total weight diff: 54529.172939, Max weight diff: 33077.875000
# mse and l0 loss: 7906979.0
# R_loss: 0.9206675887107849
# Average R_score: 0.0793323889374733
# gradient_norm: 12.244649887084961
# Total weight diff: 59158.821045, Max weight diff: 32610.361328
# mse and l0 loss: 3107701.25
# R_loss: 0.9213019609451294
# Average R_score: 0.07869803160429001
# gradient_norm: 4.850063800811768
# Total weight diff: 62217.483489, Max weight diff: 31635.375000
# mse and l0 loss: 1583336.125
# R_loss: 0.909674346446991
# Average R_score: 0.09032567590475082
# gradient_norm: 2.4583096504211426
# Total weight diff: 58248.247095, Max weight diff: 30093.962891
# mse and l0 loss: 1380177.625
# R_loss: 0.9112579226493835
# Average R_score: 0.08874206244945526
# gradient_norm: 3.275151252746582
# Total weight diff: 53685.862740, Max weight diff: 27790.550781
# mse and l0 loss: 4274911.0
# R_loss: 0.9099409580230713
# Average R_score: 0.09005904197692871
# gradient_norm: 4.697411060333252
# Total weight diff: 45933.858646, Max weight diff: 25155.501953
# mse and l0 loss: 3555088.75
# R_loss: 0.896052360534668
# Average R_score: 0.10394766181707382
# gradient_norm: 3.6319594383239746
# Total weight diff: 45317.862131, Max weight diff: 24814.500000
# mse and l0 loss: 2569821.75
# R_loss: 0.921013355255127
# Average R_score: 0.07898662239313126
# gradient_norm: 2.827784776687622
# Total weight diff: 44024.180832, Max weight diff: 23678.916016
# mse and l0 loss: 945337.375
# R_loss: 0.8951824307441711
# Average R_score: 0.10481759160757065
# gradient_norm: 1.1595841646194458
# Total weight diff: 39329.436502, Max weight diff: 21474.685547
# mse and l0 loss: 1102240.25
# R_loss: 0.8991628885269165
# Average R_score: 0.10083714127540588
# gradient_norm: 1.660726547241211
# Total weight diff: 35357.597153, Max weight diff: 20032.433594
# mse and l0 loss: 2056346.0
# R_loss: 0.8879698514938354
# Average R_score: 0.11203011870384216
# gradient_norm: 2.612147808074951
# Total weight diff: 34586.019660, Max weight diff: 19560.171875
# mse and l0 loss: 3551144.0
# R_loss: 0.914821207523346
# Average R_score: 0.08517879992723465
# gradient_norm: 4.7565202713012695
# Total weight diff: 35912.961482, Max weight diff: 20268.738281
# mse and l0 loss: 2848773.75
# R_loss: 0.8745324611663818
# Average R_score: 0.12546753883361816
# gradient_norm: 3.3577818870544434
# Total weight diff: 35682.623050, Max weight diff: 20522.730469
# mse and l0 loss: 882323.125
# R_loss: 0.9184600710868835
# Average R_score: 0.08153995126485825
# gradient_norm: 1.4253588914871216
# Total weight diff: 33654.174371, Max weight diff: 19346.851562
# mse and l0 loss: 4272281.0
# R_loss: 0.918898344039917
# Average R_score: 0.08110163360834122
# gradient_norm: 4.913211345672607
# Total weight diff: 39798.817798, Max weight diff: 20783.056641
# mse and l0 loss: 1127721.625
# R_loss: 0.9074242115020752
# Average R_score: 0.09257575869560242
# gradient_norm: 2.4542605876922607
# Total weight diff: 37137.112417, Max weight diff: 20004.316406
# mse and l0 loss: 295986.6875
# R_loss: 0.8586722612380981
# Average R_score: 0.14132770895957947
# gradient_norm: 0.6586602330207825
# Total weight diff: 34123.614976, Max weight diff: 18299.951172
# mse and l0 loss: 4419111.0
# R_loss: 0.8859871625900269
# Average R_score: 0.11401282250881195
# gradient_norm: 5.46714448928833
# Total weight diff: 32873.503396, Max weight diff: 19114.880859
# mse and l0 loss: 1845026.25
# R_loss: 0.911094605922699
# Average R_score: 0.08890537172555923
# gradient_norm: 2.5238375663757324
# Total weight diff: 30840.135183, Max weight diff: 17603.107422
# mse and l0 loss: 1062927.875
# R_loss: 0.9112130999565125
# Average R_score: 0.08878691494464874
# gradient_norm: 1.5572539567947388
# Total weight diff: 28949.706520, Max weight diff: 16101.013672
# mse and l0 loss: 6708298.0
# R_loss: 0.8882997035980225
# Average R_score: 0.11170026659965515
# gradient_norm: 7.124619483947754
# Total weight diff: 45090.131938, Max weight diff: 23319.736328
# mse and l0 loss: 683911.0625
# R_loss: 0.9208143949508667
# Average R_score: 0.0791855975985527
# gradient_norm: 1.0285859107971191
# Total weight diff: 41381.470194, Max weight diff: 21419.457031
# mse and l0 loss: 1158123.625
# R_loss: 0.884560763835907
# Average R_score: 0.11543922871351242
# gradient_norm: 2.405332326889038
# Total weight diff: 38471.839205, Max weight diff: 19852.453125
# mse and l0 loss: 3562100.0
# R_loss: 0.9054903984069824
# Average R_score: 0.09450960904359818
# gradient_norm: 5.414774417877197
# Total weight diff: 39002.802768, Max weight diff: 20664.937500
# mse and l0 loss: 611358.5625
# R_loss: 0.8533810377120972
# Average R_score: 0.14661893248558044
# gradient_norm: 0.97127366065979
# Total weight diff: 35413.585950, Max weight diff: 18923.044922
# mse and l0 loss: 1638122.375
# R_loss: 0.8565965294837952
# Average R_score: 0.14340345561504364
# gradient_norm: 2.1976916790008545
# Total weight diff: 32517.849687, Max weight diff: 17787.093750
# mse and l0 loss: 902460.8125
# R_loss: 0.8580322265625
# Average R_score: 0.1419677734375
# gradient_norm: 1.2575109004974365
# Total weight diff: 29881.764046, Max weight diff: 16547.445312
# mse and l0 loss: 833399.5
# R_loss: 0.8582587838172913
# Average R_score: 0.14174121618270874
# gradient_norm: 1.1232064962387085
# Total weight diff: 27601.673487, Max weight diff: 15581.805664
# mse and l0 loss: 1029350.4375
# R_loss: 0.9019666910171509
# Average R_score: 0.09803331643342972
# gradient_norm: 1.32394540309906
# Total weight diff: 25975.798025, Max weight diff: 14819.744141
# mse and l0 loss: 1534687.25
# R_loss: 0.8284041881561279
# Average R_score: 0.17159584164619446
# gradient_norm: 1.609171986579895
# Total weight diff: 25714.563079, Max weight diff: 14927.439453
# mse and l0 loss: 339295.9375
# R_loss: 0.8848345279693604
# Average R_score: 0.11516544222831726
# gradient_norm: 0.5408841371536255
# Total weight diff: 23669.479313, Max weight diff: 13906.357422
# mse and l0 loss: 1165437.625
# R_loss: 0.8667728900909424
# Average R_score: 0.13322710990905762
# gradient_norm: 1.6166774034500122
# Total weight diff: 22589.278062, Max weight diff: 13261.431641
# mse and l0 loss: 633275.0
# R_loss: 0.841774046421051
# Average R_score: 0.15822593867778778
# gradient_norm: 1.1284089088439941
# Total weight diff: 21258.940300, Max weight diff: 12738.106445
# mse and l0 loss: 170201.578125
# R_loss: 0.9154534339904785
# Average R_score: 0.08454658091068268
# gradient_norm: 0.3133317828178406
# Total weight diff: 19473.051604, Max weight diff: 11709.003906
# mse and l0 loss: 705065.625
# R_loss: 0.8219068050384521
# Average R_score: 0.17809319496154785
# gradient_norm: 1.091494083404541
# Total weight diff: 18969.835091, Max weight diff: 11123.463867
# mse and l0 loss: 1202395.75
# R_loss: 0.8964809775352478
# Average R_score: 0.1035190299153328
# gradient_norm: 1.9566025733947754
# Total weight diff: 20650.759534, Max weight diff: 11628.470703
# mse and l0 loss: 266886.0
# R_loss: 0.8988397121429443
# Average R_score: 0.10116025805473328
# gradient_norm: 0.464116632938385
# Total weight diff: 19002.064481, Max weight diff: 10778.642578
# mse and l0 loss: 693882.6875
# R_loss: 0.8485885858535767
# Average R_score: 0.15141141414642334
# gradient_norm: 0.8925844430923462
# Total weight diff: 17189.305110, Max weight diff: 10377.203125
# mse and l0 loss: 622636.5625
# R_loss: 0.8091518878936768
# Average R_score: 0.19084809720516205
# gradient_norm: 0.712734580039978
# Total weight diff: 16501.672159, Max weight diff: 10059.058594
# mse and l0 loss: 408944.84375
# R_loss: 0.789736270904541
# Average R_score: 0.21026374399662018
# gradient_norm: 0.5434750318527222
# Total weight diff: 15972.618518, Max weight diff: 9640.046875
# mse and l0 loss: 155858.640625
# R_loss: 0.8120856881141663
# Average R_score: 0.18791429698467255
# gradient_norm: 0.25474056601524353
# Total weight diff: 14796.998548, Max weight diff: 8940.616211
# mse and l0 loss: 154925.125
# R_loss: 0.8938932418823242
# Average R_score: 0.10610677301883698
# gradient_norm: 0.2877008616924286
# Total weight diff: 13607.626911, Max weight diff: 8222.218750
# mse and l0 loss: 350154.25
# R_loss: 0.8216205835342407
# Average R_score: 0.17837940156459808
# gradient_norm: 0.5309350490570068
# Total weight diff: 12959.865056, Max weight diff: 7692.302734
# mse and l0 loss: 1034653.0625
# R_loss: 0.8288654088973999
# Average R_score: 0.17113462090492249
# gradient_norm: 1.287830114364624
# Total weight diff: 16545.776670, Max weight diff: 8463.085938
# mse and l0 loss: 158186.421875
# R_loss: 0.9090331792831421
# Average R_score: 0.09096679091453552
# gradient_norm: 0.2535560429096222
# Total weight diff: 15231.296166, Max weight diff: 7794.625000
# mse and l0 loss: 325240.15625
# R_loss: 0.9081419110298157
# Average R_score: 0.09185808151960373
# gradient_norm: 0.5982170701026917
# Total weight diff: 14591.356444, Max weight diff: 7329.357422
# mse and l0 loss: 240521.75
# R_loss: 0.7983647584915161
# Average R_score: 0.2016352415084839
# gradient_norm: 0.35156092047691345
# Total weight diff: 13347.604220, Max weight diff: 6725.423828
# mse and l0 loss: 728002.3125
# R_loss: 0.8254343271255493
# Average R_score: 0.17456570267677307
# gradient_norm: 1.0783536434173584
# Total weight diff: 13033.883970, Max weight diff: 6963.063477
# mse and l0 loss: 234327.203125
# R_loss: 0.9103662967681885
# Average R_score: 0.08963369578123093
# gradient_norm: 0.3647240996360779
# Total weight diff: 12688.836008, Max weight diff: 6720.562012
# mse and l0 loss: 130497.265625
# R_loss: 0.747677206993103
# Average R_score: 0.2523227632045746
# gradient_norm: 0.2511776089668274
# Total weight diff: 11703.500808, Max weight diff: 6209.491211
# mse and l0 loss: 40783.078125
# R_loss: 0.9020591378211975
# Average R_score: 0.09794088453054428
# gradient_norm: 0.15585748851299286
# Total weight diff: 10679.301086, Max weight diff: 5687.367188
# mse and l0 loss: 693405.9375
# R_loss: 0.8143668174743652
# Average R_score: 0.18563316762447357
# gradient_norm: 1.0590537786483765
# Total weight diff: 12925.103840, Max weight diff: 6858.203613
# mse and l0 loss: 121559.15625
# R_loss: 0.9072468280792236
# Average R_score: 0.09275320172309875
# gradient_norm: 0.22079864144325256
# Total weight diff: 12163.540660, Max weight diff: 6515.718750
# mse and l0 loss: 176257.25
# R_loss: 0.8662542104721069
# Average R_score: 0.13374580442905426
# gradient_norm: 0.33762994408607483
# Total weight diff: 11163.653582, Max weight diff: 5910.040527
# mse and l0 loss: 70357.3046875
# R_loss: 0.8491787910461426
# Average R_score: 0.15082120895385742
# gradient_norm: 0.1688377410173416
# Total weight diff: 10141.103242, Max weight diff: 5320.435547
# mse and l0 loss: 180190.703125
# R_loss: 0.8143163919448853
# Average R_score: 0.18568363785743713
# gradient_norm: 0.3186454176902771
# Total weight diff: 8876.062729, Max weight diff: 4508.139160
# mse and l0 loss: 146349.875
# R_loss: 0.7902196645736694
# Average R_score: 0.20978032052516937
# gradient_norm: 0.2781948149204254
# Total weight diff: 8463.932460, Max weight diff: 4256.640625
# mse and l0 loss: 117266.625
# R_loss: 0.9088713526725769
# Average R_score: 0.0911286249756813
# gradient_norm: 0.2565269470214844
# Total weight diff: 7939.701860, Max weight diff: 4054.756836
# mse and l0 loss: 32837.05859375
# R_loss: 0.766672670841217
# Average R_score: 0.23332732915878296
# gradient_norm: 0.12788084149360657
# Total weight diff: 7237.949773, Max weight diff: 3717.521484
# mse and l0 loss: 24859.970703125
# R_loss: 0.8378715515136719
# Average R_score: 0.1621284782886505
# gradient_norm: 0.12810713052749634
# Total weight diff: 6624.285477, Max weight diff: 3402.032227
# mse and l0 loss: 146488.65625
# R_loss: 0.8745478391647339
# Average R_score: 0.12545214593410492
# gradient_norm: 0.2981540262699127
# Total weight diff: 6521.732277, Max weight diff: 3370.677490
# mse and l0 loss: 134780.96875
# R_loss: 0.7145905494689941
# Average R_score: 0.28540945053100586
# gradient_norm: 0.2526308596134186
# Total weight diff: 6436.287449, Max weight diff: 3240.411377
# mse and l0 loss: 93262.515625
# R_loss: 0.8047835230827332
# Average R_score: 0.19521649181842804
# gradient_norm: 0.2323847860097885
# Total weight diff: 6188.127759, Max weight diff: 3125.810059
# mse and l0 loss: 81764.84375
# R_loss: 0.849933922290802
# Average R_score: 0.1500660628080368
# gradient_norm: 0.18908096849918365
# Total weight diff: 5961.560904, Max weight diff: 3022.750977
# mse and l0 loss: 119423.2734375
# R_loss: 0.7911418676376343
# Average R_score: 0.20885814726352692
# gradient_norm: 0.2990129888057709
# Total weight diff: 5994.325808, Max weight diff: 3061.777344
# mse and l0 loss: 56229.10546875
# R_loss: 0.8685224056243896
# Average R_score: 0.13147757947444916
# gradient_norm: 0.16451464593410492
# Total weight diff: 5679.574976, Max weight diff: 2902.806641
# mse and l0 loss: 68569.03125
# R_loss: 0.9084257483482361
# Average R_score: 0.09157425910234451
# gradient_norm: 0.15354399383068085
# Total weight diff: 5439.258568, Max weight diff: 2758.592773
# mse and l0 loss: 56227.2890625
# R_loss: 0.700888991355896
# Average R_score: 0.2991110384464264
# gradient_norm: 0.1402617245912552
# Total weight diff: 4989.246735, Max weight diff: 2584.056641
# mse and l0 loss: 25710.857421875
# R_loss: 0.6913135647773743
# Average R_score: 0.30868643522262573
# gradient_norm: 0.10964158177375793
# Total weight diff: 4535.333920, Max weight diff: 2375.931641
# mse and l0 loss: 85666.078125
# R_loss: 0.7431759238243103
# Average R_score: 0.2568240761756897
# gradient_norm: 0.1920509785413742
# Total weight diff: 4550.903656, Max weight diff: 2352.135498
# mse and l0 loss: 43532.78125
# R_loss: 0.8092927932739258
# Average R_score: 0.19070720672607422
# gradient_norm: 0.1376098096370697
# Total weight diff: 4301.635513, Max weight diff: 2220.281250
# mse and l0 loss: 37912.47265625
# R_loss: 0.8687388896942139
# Average R_score: 0.13126108050346375
# gradient_norm: 0.12084847688674927
# Total weight diff: 3952.727025, Max weight diff: 2071.725586
# mse and l0 loss: 22937.162109375
# R_loss: 0.7855390906333923
# Average R_score: 0.21446089446544647
# gradient_norm: 0.10314502567052841
# Total weight diff: 3627.510289, Max weight diff: 1923.609375
# mse and l0 loss: 22704.953125
# R_loss: 0.8461836576461792
# Average R_score: 0.153816357254982
# gradient_norm: 0.14128708839416504
# Total weight diff: 3338.375975, Max weight diff: 1794.306152
# mse and l0 loss: 11819.64453125
# R_loss: 0.7676514983177185
# Average R_score: 0.2323484867811203
# gradient_norm: 0.13649830222129822
# Total weight diff: 3039.069852, Max weight diff: 1649.012695
# mse and l0 loss: 34027.4453125
# R_loss: 0.7082001566886902
# Average R_score: 0.2917998433113098
# gradient_norm: 0.12426671385765076
# Total weight diff: 2783.538422, Max weight diff: 1561.397949
# mse and l0 loss: 16693.587890625
# R_loss: 0.6727982759475708
# Average R_score: 0.3272016942501068
# gradient_norm: 0.10954118520021439
# Total weight diff: 2569.300310, Max weight diff: 1454.418213
# mse and l0 loss: 45995.08203125
# R_loss: 0.8882789611816406
# Average R_score: 0.11172102391719818
# gradient_norm: 0.13237060606479645
# Total weight diff: 2509.559056, Max weight diff: 1446.787964
# mse and l0 loss: 11666.9970703125
# R_loss: 0.8544699549674988
# Average R_score: 0.14553005993366241
# gradient_norm: 0.12456519156694412
# Total weight diff: 2307.251184, Max weight diff: 1338.816162
# mse and l0 loss: 29687.375
# R_loss: 0.6933100819587708
# Average R_score: 0.30668991804122925
# gradient_norm: 0.11757609248161316
# Total weight diff: 2190.146918, Max weight diff: 1278.891846
# mse and l0 loss: 25391.283203125
# R_loss: 0.8282647132873535
# Average R_score: 0.17173530161380768
# gradient_norm: 0.1175171285867691
# Total weight diff: 2104.354076, Max weight diff: 1231.254639
# mse and l0 loss: 19902.134765625
# R_loss: 0.675365686416626
# Average R_score: 0.324634313583374
# gradient_norm: 0.11363653093576431
# Total weight diff: 1997.227829, Max weight diff: 1167.468750
# mse and l0 loss: 14173.494140625
# R_loss: 0.8634780645370483
# Average R_score: 0.13652196526527405
# gradient_norm: 0.12488816678524017
# Total weight diff: 1873.680296, Max weight diff: 1098.059204
# mse and l0 loss: 18588.3984375
# R_loss: 0.6172884106636047
# Average R_score: 0.38271158933639526
# gradient_norm: 0.10881325602531433
# Total weight diff: 1828.147412, Max weight diff: 1047.555786
# mse and l0 loss: 49072.68359375
# R_loss: 0.7762061953544617
# Average R_score: 0.22379381954669952
# gradient_norm: 0.24308256804943085
# Total weight diff: 2004.190137, Max weight diff: 1195.864014
# mse and l0 loss: 52744.0703125
# R_loss: 0.6930521726608276
# Average R_score: 0.30694785714149475
# gradient_norm: 0.1423904299736023
# Total weight diff: 2286.628582, Max weight diff: 1252.640991
# mse and l0 loss: 17782.021484375
# R_loss: 0.7913272976875305
# Average R_score: 0.20867270231246948
# gradient_norm: 0.13231161236763
# Total weight diff: 2181.055544, Max weight diff: 1190.342529
# mse and l0 loss: 78947.609375
# R_loss: 0.6983994245529175
# Average R_score: 0.3016005754470825
# gradient_norm: 0.2685423195362091
# Total weight diff: 2693.528861, Max weight diff: 1435.935913
# mse and l0 loss: 18397.994140625
# R_loss: 0.868230402469635
# Average R_score: 0.1317695826292038
# gradient_norm: 0.11935347318649292
# Total weight diff: 2513.363135, Max weight diff: 1349.247437
# mse and l0 loss: 12614.9013671875
# R_loss: 0.8611996173858643
# Average R_score: 0.13880041241645813
# gradient_norm: 0.1266724318265915
# Total weight diff: 2320.967910, Max weight diff: 1262.013794
# mse and l0 loss: 20373.92578125
# R_loss: 0.6801589131355286
# Average R_score: 0.31984108686447144
# gradient_norm: 0.10576426982879639
# Total weight diff: 2201.140703, Max weight diff: 1197.510498
# mse and l0 loss: 10355.98828125
# R_loss: 0.6586753129959106
# Average R_score: 0.34132465720176697
# gradient_norm: 0.09552501887083054
# Total weight diff: 2040.718298, Max weight diff: 1110.035889
# mse and l0 loss: 12542.4033203125
# R_loss: 0.8417014479637146
# Average R_score: 0.1582985371351242
# gradient_norm: 0.0928119495511055
# Total weight diff: 1915.049789, Max weight diff: 1044.210449
# mse and l0 loss: 21513.01953125
# R_loss: 0.8681296110153198
# Average R_score: 0.13187041878700256
# gradient_norm: 0.12303362786769867
# Total weight diff: 1878.557178, Max weight diff: 1020.581970
# mse and l0 loss: 9857.0244140625
# R_loss: 0.7012733817100525
# Average R_score: 0.2987266182899475
# gradient_norm: 0.11363780498504639
# Total weight diff: 1724.657260, Max weight diff: 947.677063
# mse and l0 loss: 47035.65625
# R_loss: 0.6079233884811401
# Average R_score: 0.39207664132118225
# gradient_norm: 0.13239677250385284
# Total weight diff: 1836.073235, Max weight diff: 1057.921875
# mse and l0 loss: 11020.291015625
# R_loss: 0.5946921706199646
# Average R_score: 0.4053078293800354
# gradient_norm: 0.08179433643817902
# Total weight diff: 1688.375528, Max weight diff: 982.145874
# mse and l0 loss: 36541.5234375
# R_loss: 0.726981520652771
# Average R_score: 0.2730185091495514
# gradient_norm: 0.11193447560071945
# Total weight diff: 1714.179677, Max weight diff: 1031.450928
# mse and l0 loss: 16954.052734375
# R_loss: 0.7294610738754272
# Average R_score: 0.27053895592689514
# gradient_norm: 0.12065790593624115
# Total weight diff: 1641.262043, Max weight diff: 980.459473
# mse and l0 loss: 23607.71875
# R_loss: 0.8600276708602905
# Average R_score: 0.13997234404087067
# gradient_norm: 0.12132124602794647
# Total weight diff: 1643.693438, Max weight diff: 978.091675
# mse and l0 loss: 41858.52734375
# R_loss: 0.7706375122070312
# Average R_score: 0.22936245799064636
# gradient_norm: 0.13545890152454376
# Total weight diff: 1708.408906, Max weight diff: 1034.653076
# mse and l0 loss: 17204.470703125
# R_loss: 0.6030193567276001
# Average R_score: 0.3969806134700775
# gradient_norm: 0.08421420305967331
# Total weight diff: 1687.163315, Max weight diff: 996.764404
# mse and l0 loss: 13012.7392578125
# R_loss: 0.8166557550430298
# Average R_score: 0.1833442598581314
# gradient_norm: 0.10690081119537354
# Total weight diff: 1628.633392, Max weight diff: 953.131897
# mse and l0 loss: 8769.60546875
# R_loss: 0.6977019309997559
# Average R_score: 0.30229803919792175
# gradient_norm: 0.10278148204088211
# Total weight diff: 1513.005483, Max weight diff: 882.622681
# mse and l0 loss: 9046.2265625
# R_loss: 0.5296815633773804
# Average R_score: 0.47031840682029724
# gradient_norm: 0.07932256162166595
# Total weight diff: 1415.874388, Max weight diff: 819.049683
# mse and l0 loss: 35312.30859375
# R_loss: 0.8163917660713196
# Average R_score: 0.18360821902751923
# gradient_norm: 0.11468899250030518
# Total weight diff: 1608.198399, Max weight diff: 919.910645
# mse and l0 loss: 21281.07421875
# R_loss: 0.760843813419342
# Average R_score: 0.23915617167949677
# gradient_norm: 0.11226600408554077
# Total weight diff: 1750.881256, Max weight diff: 959.400269
# mse and l0 loss: 77593.75
# R_loss: 0.6775288581848145
# Average R_score: 0.32247117161750793
# gradient_norm: 0.17476072907447815
# Total weight diff: 3227.393480, Max weight diff: 1770.764404
# mse and l0 loss: 8721.3203125
# R_loss: 0.5889222621917725
# Average R_score: 0.4110777676105499
# gradient_norm: 0.10969623923301697
# Total weight diff: 2950.666486, Max weight diff: 1616.834351
# mse and l0 loss: 25347.876953125
# R_loss: 0.6206458806991577
# Average R_score: 0.3793541193008423
# gradient_norm: 0.1328052133321762
# Total weight diff: 2729.004609, Max weight diff: 1442.338013
# mse and l0 loss: 14692.9501953125
# R_loss: 0.8302571177482605
# Average R_score: 0.1697428822517395
# gradient_norm: 0.14547458291053772
# Total weight diff: 2544.530195, Max weight diff: 1338.475830
# mse and l0 loss: 31901.56640625
# R_loss: 0.6009587049484253
# Average R_score: 0.3990412950515747
# gradient_norm: 0.15374433994293213
# Total weight diff: 2386.205735, Max weight diff: 1196.490723
# mse and l0 loss: 8592.0380859375
# R_loss: 0.6395576000213623
# Average R_score: 0.3604423999786377
# gradient_norm: 0.115910105407238
# Total weight diff: 2146.346524, Max weight diff: 1087.858154
# mse and l0 loss: 8849.0478515625
# R_loss: 0.8449225425720215
# Average R_score: 0.15507742762565613
# gradient_norm: 0.24441446363925934
# Total weight diff: 1984.870872, Max weight diff: 1018.335266
# mse and l0 loss: 7508.08251953125
# R_loss: 0.5847346186637878
# Average R_score: 0.41526538133621216
# gradient_norm: 0.0963720977306366
# Total weight diff: 1803.929301, Max weight diff: 929.046570
# mse and l0 loss: 11404.5927734375
# R_loss: 0.6058527231216431
# Average R_score: 0.3941473066806793
# gradient_norm: 0.0910361260175705
# Total weight diff: 1605.619257, Max weight diff: 855.770996
# mse and l0 loss: 17591.150390625
# R_loss: 0.7816077470779419
# Average R_score: 0.2183922678232193
# gradient_norm: 0.09693876653909683
# Total weight diff: 1443.167326, Max weight diff: 829.574341
# mse and l0 loss: 15392.4248046875
# R_loss: 0.6910393238067627
# Average R_score: 0.3089607059955597
# gradient_norm: 0.1290930062532425
# Total weight diff: 1349.554811, Max weight diff: 812.561401
# mse and l0 loss: 22999.48046875
# R_loss: 0.6905006170272827
# Average R_score: 0.3094993829727173
# gradient_norm: 0.12051287293434143
# Total weight diff: 1316.736010, Max weight diff: 838.927002
# mse and l0 loss: 26072.458984375
# R_loss: 0.775973916053772
# Average R_score: 0.22402606904506683
# gradient_norm: 0.12415257841348648
# Total weight diff: 1399.767314, Max weight diff: 889.718384
# mse and l0 loss: 10933.990234375
# R_loss: 0.8008638024330139
# Average R_score: 0.19913621246814728
# gradient_norm: 0.12657524645328522
# Total weight diff: 1334.072916, Max weight diff: 841.212402
# mse and l0 loss: 9671.5986328125
# R_loss: 0.5576184988021851
# Average R_score: 0.44238150119781494
# gradient_norm: 0.07854224741458893
# Total weight diff: 1254.689810, Max weight diff: 779.835449
# mse and l0 loss: 7602.794921875
# R_loss: 0.6291630268096924
# Average R_score: 0.3708369731903076
# gradient_norm: 0.08064320683479309
# Total weight diff: 1157.682243, Max weight diff: 719.484741
# mse and l0 loss: 43924.46875
# R_loss: 0.6605796813964844
# Average R_score: 0.3394203186035156
# gradient_norm: 0.17888641357421875
# Total weight diff: 1861.920791, Max weight diff: 1002.902466
# mse and l0 loss: 13147.38671875
# R_loss: 0.860370397567749
# Average R_score: 0.1396295726299286
# gradient_norm: 0.12453519552946091
# Total weight diff: 1740.250870, Max weight diff: 942.761536
# mse and l0 loss: 30938.001953125
# R_loss: 0.5755794048309326
# Average R_score: 0.4244205951690674
# gradient_norm: 0.10650992393493652
# Total weight diff: 2081.782190, Max weight diff: 1108.354004
# mse and l0 loss: 59330.0078125
# R_loss: 0.6045843958854675
# Average R_score: 0.39541560411453247
# gradient_norm: 0.1887838989496231
# Total weight diff: 3158.771226, Max weight diff: 1814.050537
# mse and l0 loss: 9216.3388671875
# R_loss: 0.8492209315299988
# Average R_score: 0.15077908337116241
# gradient_norm: 0.11281925439834595
# Total weight diff: 2894.004987, Max weight diff: 1653.643311
# mse and l0 loss: 6494.4267578125
# R_loss: 0.8443204164505005
# Average R_score: 0.1556795835494995
# gradient_norm: 0.11985089629888535
# Total weight diff: 2629.612267, Max weight diff: 1493.224365
# mse and l0 loss: 10050.2998046875
# R_loss: 0.6175227761268616
# Average R_score: 0.3824772238731384
# gradient_norm: 0.09004360437393188
# Total weight diff: 2386.770782, Max weight diff: 1343.100220
# mse and l0 loss: 12956.2763671875
# R_loss: 0.5928059816360474
# Average R_score: 0.40719401836395264
# gradient_norm: 0.07973223924636841
# Total weight diff: 2202.450974, Max weight diff: 1231.576416
# mse and l0 loss: 29128.083984375
# R_loss: 0.7676897048950195
# Average R_score: 0.23231032490730286
# gradient_norm: 0.10593446344137192
# Total weight diff: 1935.307307, Max weight diff: 983.072937
# mse and l0 loss: 10170.060546875
# R_loss: 0.7237988114356995
# Average R_score: 0.27620118856430054
# gradient_norm: 0.08926723152399063
# Total weight diff: 1756.311729, Max weight diff: 884.515259
# mse and l0 loss: 14723.46484375
# R_loss: 0.5541203618049622
# Average R_score: 0.44587963819503784
# gradient_norm: 0.08550821244716644
# Total weight diff: 1582.342108, Max weight diff: 837.103638
# mse and l0 loss: 10059.3662109375
# R_loss: 0.8324381113052368
# Average R_score: 0.167561873793602
# gradient_norm: 0.1163773462176323
# Total weight diff: 1450.769144, Max weight diff: 786.051514
# mse and l0 loss: 8155.94970703125
# R_loss: 0.7562022805213928
# Average R_score: 0.24379773437976837
# gradient_norm: 0.13552680611610413
# Total weight diff: 1334.947997, Max weight diff: 733.749756
# mse and l0 loss: 11206.912109375
# R_loss: 0.5953235626220703
# Average R_score: 0.4046764075756073
# gradient_norm: 0.07688204199075699
# Total weight diff: 1224.036950, Max weight diff: 690.151123
# mse and l0 loss: 9895.435546875
# R_loss: 0.7154085636138916
# Average R_score: 0.284591406583786
# gradient_norm: 0.11336557567119598
# Total weight diff: 1110.306957, Max weight diff: 650.002319
# mse and l0 loss: 10696.107421875
# R_loss: 0.6597865223884583
# Average R_score: 0.34021347761154175
# gradient_norm: 0.15979154407978058
# Total weight diff: 1065.285027, Max weight diff: 634.151855
# mse and l0 loss: 7663.8779296875
# R_loss: 0.5614782571792603
# Average R_score: 0.43852177262306213
# gradient_norm: 0.07100945711135864
# Total weight diff: 979.472149, Max weight diff: 591.657715
# mse and l0 loss: 8079.13427734375
# R_loss: 0.6789368391036987
# Average R_score: 0.32106319069862366
# gradient_norm: 0.1615394800901413
# Total weight diff: 894.531679, Max weight diff: 542.497131
# mse and l0 loss: 8846.3486328125
# R_loss: 0.60555100440979
# Average R_score: 0.39444899559020996
# gradient_norm: 0.07094706594944
# Total weight diff: 842.169102, Max weight diff: 513.208923
# mse and l0 loss: 11166.72265625
# R_loss: 0.6671962738037109
# Average R_score: 0.3328036963939667
# gradient_norm: 0.07318483293056488
# Total weight diff: 801.635657, Max weight diff: 497.313324
# mse and l0 loss: 7207.595703125
# R_loss: 0.734534740447998
# Average R_score: 0.26546528935432434
# gradient_norm: 0.10364100337028503
# Total weight diff: 747.571367, Max weight diff: 468.838745
# mse and l0 loss: 6239.8515625
# R_loss: 0.5362146496772766
# Average R_score: 0.4637853503227234
# gradient_norm: 0.07097037881612778
# Total weight diff: 690.018467, Max weight diff: 432.195190
# mse and l0 loss: 7522.2041015625
# R_loss: 0.5253926515579224
# Average R_score: 0.4746073782444
# gradient_norm: 0.07590440660715103
# Total weight diff: 645.217176, Max weight diff: 408.917664
# mse and l0 loss: 8591.6650390625
# R_loss: 0.7515962719917297
# Average R_score: 0.24840374290943146
# gradient_norm: 0.11354216933250427
# Total weight diff: 644.686270, Max weight diff: 411.367004
# mse and l0 loss: 22787.978515625
# R_loss: 0.638992428779602
# Average R_score: 0.36100757122039795
# gradient_norm: 0.10791217535734177
# Total weight diff: 869.669798, Max weight diff: 542.314575
# mse and l0 loss: 24695.94921875
# R_loss: 0.6460527181625366
# Average R_score: 0.35394731163978577
# gradient_norm: 0.09023130685091019
# Total weight diff: 1223.836669, Max weight diff: 645.364685
# mse and l0 loss: 6800.28466796875
# R_loss: 0.5187568664550781
# Average R_score: 0.48124316334724426
# gradient_norm: 0.07081513106822968
# Total weight diff: 1124.491519, Max weight diff: 593.002502
# mse and l0 loss: 8577.869140625
# R_loss: 0.5660722851753235
# Average R_score: 0.4339277148246765
# gradient_norm: 0.07199086993932724
# Total weight diff: 1088.909098, Max weight diff: 561.729248
# mse and l0 loss: 9168.169921875
# R_loss: 0.5368459224700928
# Average R_score: 0.4631540775299072
# gradient_norm: 0.06802601367235184
# Total weight diff: 1054.950179, Max weight diff: 539.633728
# mse and l0 loss: 8740.568359375
# R_loss: 0.7180030941963196
# Average R_score: 0.2819969058036804
# gradient_norm: 0.10023873299360275
# Total weight diff: 1014.823534, Max weight diff: 515.452576
# mse and l0 loss: 7604.05126953125
# R_loss: 0.7616493701934814
# Average R_score: 0.23835061490535736
# gradient_norm: 0.08056420832872391
# Total weight diff: 954.063238, Max weight diff: 486.320801
# mse and l0 loss: 9051.1533203125
# R_loss: 0.5241276621818542
# Average R_score: 0.47587233781814575
# gradient_norm: 0.07982435822486877
# Total weight diff: 948.011919, Max weight diff: 476.789825
# mse and l0 loss: 6459.63671875
# R_loss: 0.7625342607498169
# Average R_score: 0.23746570944786072
# gradient_norm: 0.0952090248465538
# Total weight diff: 868.515455, Max weight diff: 441.947083
# mse and l0 loss: 11774.4912109375
# R_loss: 0.7393475770950317
# Average R_score: 0.26065242290496826
# gradient_norm: 0.10123249143362045
# Total weight diff: 877.444151, Max weight diff: 460.701477
# mse and l0 loss: 10602.6884765625
# R_loss: 0.6164254546165466
# Average R_score: 0.38357454538345337
# gradient_norm: 0.07728811353445053
# Total weight diff: 915.851452, Max weight diff: 470.381836
# mse and l0 loss: 8359.4814453125
# R_loss: 0.7561632394790649
# Average R_score: 0.24383677542209625
# gradient_norm: 0.07953307777643204
# Total weight diff: 916.642624, Max weight diff: 459.494995
# mse and l0 loss: 11204.8251953125
# R_loss: 0.7759535312652588
# Average R_score: 0.2240464985370636
# gradient_norm: 0.09368287026882172
# Total weight diff: 983.963992, Max weight diff: 506.478210
# mse and l0 loss: 13481.0576171875
# R_loss: 0.580856442451477
# Average R_score: 0.41914358735084534
# gradient_norm: 0.08406740427017212
# Total weight diff: 1111.049066, Max weight diff: 597.810425
# mse and l0 loss: 9392.06640625
# R_loss: 0.6076450347900391
# Average R_score: 0.3923549950122833
# gradient_norm: 0.0818193107843399
# Total weight diff: 1035.116004, Max weight diff: 531.870422
# mse and l0 loss: 10383.486328125
# R_loss: 0.6013180017471313
# Average R_score: 0.39868202805519104
# gradient_norm: 0.06890984624624252
# Total weight diff: 1022.665508, Max weight diff: 526.408447
# mse and l0 loss: 6042.9638671875
# R_loss: 0.7995312809944153
# Average R_score: 0.20046871900558472
# gradient_norm: 0.11355617642402649
# Total weight diff: 938.192083, Max weight diff: 474.462036
# mse and l0 loss: 7313.29052734375
# R_loss: 0.6460633277893066
# Average R_score: 0.35393664240837097
# gradient_norm: 0.08688205480575562
# Total weight diff: 862.240508, Max weight diff: 436.766296
# mse and l0 loss: 7418.07568359375
# R_loss: 0.5096633434295654
# Average R_score: 0.49033665657043457
# gradient_norm: 0.06435807794332504
# Total weight diff: 781.986399, Max weight diff: 413.041534
# mse and l0 loss: 25535.4765625
# R_loss: 0.5723316669464111
# Average R_score: 0.42766836285591125
# gradient_norm: 0.10677102953195572
# Total weight diff: 936.726562, Max weight diff: 579.255737
# mse and l0 loss: 10149.95703125
# R_loss: 0.5156664848327637
# Average R_score: 0.4843335449695587
# gradient_norm: 0.0817544013261795
# Total weight diff: 889.000446, Max weight diff: 551.368347
# mse and l0 loss: 7652.0166015625
# R_loss: 0.5496443510055542
# Average R_score: 0.4503556489944458
# gradient_norm: 0.07286146283149719
# Total weight diff: 829.376329, Max weight diff: 518.894653
# mse and l0 loss: 12611.888671875
# R_loss: 0.5798609256744385
# Average R_score: 0.42013904452323914
# gradient_norm: 0.06899754703044891
# Total weight diff: 867.216623, Max weight diff: 526.553101
# mse and l0 loss: 7466.7705078125
# R_loss: 0.639813244342804
# Average R_score: 0.36018675565719604
# gradient_norm: 0.07208434492349625
# Total weight diff: 809.557271, Max weight diff: 492.629822
# mse and l0 loss: 8169.59765625
# R_loss: 0.796506404876709
# Average R_score: 0.20349359512329102
# gradient_norm: 0.08288361877202988
# Total weight diff: 781.946699, Max weight diff: 473.499146
# mse and l0 loss: 7783.0185546875
# R_loss: 0.5657440423965454
# Average R_score: 0.4342559576034546
# gradient_norm: 0.05994601547718048
# Total weight diff: 745.359557, Max weight diff: 450.984161
# mse and l0 loss: 10809.494140625
# R_loss: 0.765203058719635
# Average R_score: 0.23479695618152618
# gradient_norm: 0.08798955380916595
# Total weight diff: 795.015850, Max weight diff: 465.765991
# mse and l0 loss: 9006.8603515625
# R_loss: 0.5746027231216431
# Average R_score: 0.42539727687835693
# gradient_norm: 0.06024068221449852
# Total weight diff: 779.813288, Max weight diff: 452.960083
# mse and l0 loss: 29653.59375
# R_loss: 0.8647125959396362
# Average R_score: 0.13528738915920258
# gradient_norm: 0.12511958181858063
# Total weight diff: 1167.747782, Max weight diff: 703.049072
# mse and l0 loss: 6311.58203125
# R_loss: 0.6410500407218933
# Average R_score: 0.3589499592781067
# gradient_norm: 0.07455889880657196
# Total weight diff: 1076.025892, Max weight diff: 648.522522
# mse and l0 loss: 8509.197265625
# R_loss: 0.7692688703536987
# Average R_score: 0.23073115944862366
# gradient_norm: 0.0835094004869461
# Total weight diff: 1080.156400, Max weight diff: 631.111816
# mse and l0 loss: 7181.3623046875
# R_loss: 0.7560930848121643
# Average R_score: 0.2439069002866745
# gradient_norm: 0.10828214138746262
# Total weight diff: 1007.921352, Max weight diff: 588.954468
# mse and l0 loss: 6930.2900390625
# R_loss: 0.6419274806976318
# Average R_score: 0.3580724895000458
# gradient_norm: 0.07795386761426926
# Total weight diff: 940.751818, Max weight diff: 551.818420
# mse and l0 loss: 6833.33154296875
# R_loss: 0.6823101043701172
# Average R_score: 0.3176899254322052
# gradient_norm: 0.07731739431619644
# Total weight diff: 871.421285, Max weight diff: 516.207764
# mse and l0 loss: 6751.4853515625
# R_loss: 0.7019351720809937
# Average R_score: 0.29806482791900635
# gradient_norm: 0.09115096181631088
# Total weight diff: 811.707013, Max weight diff: 483.419128
# mse and l0 loss: 7324.12841796875
# R_loss: 0.5490244626998901
# Average R_score: 0.45097553730010986
# gradient_norm: 0.06775309145450592
# Total weight diff: 783.915419, Max weight diff: 464.264648
# mse and l0 loss: 6167.345703125
# R_loss: 0.5087020993232727
# Average R_score: 0.4912979006767273
# gradient_norm: 0.06245673447847366
# Total weight diff: 713.249631, Max weight diff: 427.245270
# mse and l0 loss: 6693.7822265625
# R_loss: 0.8210170269012451
# Average R_score: 0.17898300290107727
# gradient_norm: 0.11000974476337433
# Total weight diff: 684.962256, Max weight diff: 408.200012
# mse and l0 loss: 31261.12109375
# R_loss: 0.5675632953643799
# Average R_score: 0.4324367046356201
# gradient_norm: 0.10515747219324112
# Total weight diff: 1169.766976, Max weight diff: 657.244019
# mse and l0 loss: 8243.3916015625
# R_loss: 0.4739406108856201
# Average R_score: 0.5260593891143799
# gradient_norm: 0.06925735622644424
# Total weight diff: 1080.976266, Max weight diff: 611.932861
# mse and l0 loss: 9958.1025390625
# R_loss: 0.5869573950767517
# Average R_score: 0.4130426049232483
# gradient_norm: 0.10938237607479095
# Total weight diff: 1074.624336, Max weight diff: 608.370605
# mse and l0 loss: 6040.4287109375
# R_loss: 0.6120126843452454
# Average R_score: 0.38798731565475464
# gradient_norm: 0.08103031665086746
# Total weight diff: 985.366032, Max weight diff: 558.859375
# mse and l0 loss: 7391.87255859375
# R_loss: 0.8441241383552551
# Average R_score: 0.15587584674358368
# gradient_norm: 0.09103512018918991
# Total weight diff: 918.804370, Max weight diff: 535.124634
# mse and l0 loss: 6523.3125
# R_loss: 0.6978957056999207
# Average R_score: 0.30210429430007935
# gradient_norm: 0.08600778877735138
# Total weight diff: 833.844524, Max weight diff: 498.513763
# mse and l0 loss: 7835.6103515625
# R_loss: 0.7757766246795654
# Average R_score: 0.22422339022159576
# gradient_norm: 0.10962702333927155
# Total weight diff: 789.556297, Max weight diff: 477.192871
# mse and l0 loss: 10023.0166015625
# R_loss: 0.8070077896118164
# Average R_score: 0.1929922103881836
# gradient_norm: 0.1127593144774437
# Total weight diff: 775.841745, Max weight diff: 473.356445
# mse and l0 loss: 7951.02294921875
# R_loss: 0.6955183744430542
# Average R_score: 0.3044815957546234
# gradient_norm: 0.11732382327318192
# Total weight diff: 739.353630, Max weight diff: 453.834015
# mse and l0 loss: 13553.5986328125
# R_loss: 0.5868607759475708
# Average R_score: 0.4131392538547516
# gradient_norm: 0.0654587671160698
# Total weight diff: 828.119944, Max weight diff: 492.107788
# mse and l0 loss: 10042.017578125
# R_loss: 0.5127460360527039
# Average R_score: 0.48725396394729614
# gradient_norm: 0.0632443055510521
# Total weight diff: 784.503882, Max weight diff: 488.084900
# mse and l0 loss: 5979.04931640625
# R_loss: 0.7305148243904114
# Average R_score: 0.2694851756095886
# gradient_norm: 0.10738278925418854
# Total weight diff: 721.596522, Max weight diff: 451.561218
# mse and l0 loss: 11288.5048828125
# R_loss: 0.7928256392478943
# Average R_score: 0.20717434585094452
# gradient_norm: 0.11578135937452316
# Total weight diff: 796.535007, Max weight diff: 482.510254
# mse and l0 loss: 5820.27587890625
# R_loss: 0.5392287969589233
# Average R_score: 0.4607711732387543
# gradient_norm: 0.05453231930732727
# Total weight diff: 731.268000, Max weight diff: 442.568787
# mse and l0 loss: 6705.71826171875
# R_loss: 0.70354163646698
# Average R_score: 0.2964583933353424
# gradient_norm: 0.07842588424682617
# Total weight diff: 695.010851, Max weight diff: 423.988281
# mse and l0 loss: 6671.10205078125
# R_loss: 0.5265341997146606
# Average R_score: 0.47346580028533936
# gradient_norm: 0.06857839226722717
# Total weight diff: 659.777126, Max weight diff: 396.894745
# mse and l0 loss: 6672.32470703125
# R_loss: 0.5749847888946533
# Average R_score: 0.4250151813030243
# gradient_norm: 0.06124478206038475
# Total weight diff: 620.252873, Max weight diff: 374.093018
# mse and l0 loss: 13336.740234375
# R_loss: 0.6110508441925049
# Average R_score: 0.3889491558074951
# gradient_norm: 0.06574633717536926
# Total weight diff: 788.308248, Max weight diff: 436.839417
# mse and l0 loss: 14393.185546875
# R_loss: 0.767903208732605
# Average R_score: 0.2320968210697174
# gradient_norm: 0.08524850755929947
# Total weight diff: 979.581005, Max weight diff: 520.743164
# mse and l0 loss: 8000.5400390625
# R_loss: 0.7374024391174316
# Average R_score: 0.26259756088256836
# gradient_norm: 0.2274596244096756
# Total weight diff: 911.470514, Max weight diff: 491.895325
# mse and l0 loss: 7745.6220703125
# R_loss: 0.7642383575439453
# Average R_score: 0.23576167225837708
# gradient_norm: 0.09132153540849686
# Total weight diff: 882.232714, Max weight diff: 476.592316
# mse and l0 loss: 5601.0361328125
# R_loss: 0.7018014192581177
# Average R_score: 0.29819855093955994
# gradient_norm: 0.0928238034248352
# Total weight diff: 806.803184, Max weight diff: 439.554321
# mse and l0 loss: 6859.26953125
# R_loss: 0.8540363311767578
# Average R_score: 0.14596368372440338
# gradient_norm: 0.08449243009090424
# Total weight diff: 757.145385, Max weight diff: 418.990417
# mse and l0 loss: 8857.578125
# R_loss: 0.851932168006897
# Average R_score: 0.14806781709194183
# gradient_norm: 0.09139546751976013
# Total weight diff: 777.824124, Max weight diff: 429.322388
# mse and l0 loss: 6353.6552734375
# R_loss: 0.8025714159011841
# Average R_score: 0.19742858409881592
# gradient_norm: 0.09332703799009323
# Total weight diff: 719.548056, Max weight diff: 403.829346
# mse and l0 loss: 6464.5126953125
# R_loss: 0.7447737455368042
# Average R_score: 0.2552262842655182
# gradient_norm: 0.06991097331047058
# Total weight diff: 668.800697, Max weight diff: 381.422150
# mse and l0 loss: 6237.9775390625
# R_loss: 0.7365051507949829
# Average R_score: 0.2634948194026947
# gradient_norm: 0.08610235154628754
# Total weight diff: 628.812435, Max weight diff: 360.788391
# mse and l0 loss: 5709.24951171875
# R_loss: 0.5109847187995911
# Average R_score: 0.48901528120040894
# gradient_norm: 0.07155118137598038
# Total weight diff: 571.721570, Max weight diff: 328.823181
# mse and l0 loss: 6879.916015625
# R_loss: 0.5209402441978455
# Average R_score: 0.47905975580215454
# gradient_norm: 0.05313248932361603
# Total weight diff: 549.701828, Max weight diff: 317.636627
# mse and l0 loss: 8047.50244140625
# R_loss: 0.6855249404907227
# Average R_score: 0.31447508931159973
# gradient_norm: 0.07619352638721466
# Total weight diff: 548.357400, Max weight diff: 327.189331
# mse and l0 loss: 9959.0126953125
# R_loss: 0.7341053485870361
# Average R_score: 0.26589468121528625
# gradient_norm: 0.0697750672698021
# Total weight diff: 598.162889, Max weight diff: 366.052429
# mse and l0 loss: 6155.6123046875
# R_loss: 0.6741228103637695
# Average R_score: 0.32587721943855286
# gradient_norm: 0.07082925736904144
# Total weight diff: 567.497612, Max weight diff: 348.892120
# mse and l0 loss: 6523.2705078125
# R_loss: 0.6279354095458984
# Average R_score: 0.3720645606517792
# gradient_norm: 0.06929467618465424
# Total weight diff: 539.665359, Max weight diff: 331.069275
# mse and l0 loss: 6445.61328125
# R_loss: 0.7382371425628662
# Average R_score: 0.2617628872394562
# gradient_norm: 0.11125793308019638
# Total weight diff: 508.856179, Max weight diff: 315.296234
# mse and l0 loss: 12305.287109375
# R_loss: 0.6459084749221802
# Average R_score: 0.35409149527549744
# gradient_norm: 0.07161212712526321
# Total weight diff: 673.913505, Max weight diff: 405.131165
# mse and l0 loss: 6282.91259765625
# R_loss: 0.7100849151611328
# Average R_score: 0.2899150848388672
# gradient_norm: 0.09572052955627441
# Total weight diff: 640.985327, Max weight diff: 387.627563
# mse and l0 loss: 5522.5703125
# R_loss: 0.5301570892333984
# Average R_score: 0.46984291076660156
# gradient_norm: 0.0537664033472538
# Total weight diff: 590.529119, Max weight diff: 357.477814
# mse and l0 loss: 6585.80029296875
# R_loss: 0.7649707794189453
# Average R_score: 0.23502923548221588
# gradient_norm: 0.08375787734985352
# Total weight diff: 560.514985, Max weight diff: 344.030823
# mse and l0 loss: 8877.7431640625
# R_loss: 0.6650530695915222
# Average R_score: 0.3349469304084778
# gradient_norm: 0.0822451189160347
# Total weight diff: 634.692624, Max weight diff: 373.770203
# mse and l0 loss: 6109.78515625
# R_loss: 0.5874712467193604
# Average R_score: 0.41252875328063965
# gradient_norm: 0.057692915201187134
# Total weight diff: 587.198024, Max weight diff: 346.290588
# mse and l0 loss: 7236.60009765625
# R_loss: 0.733622133731842
# Average R_score: 0.26637786626815796
# gradient_norm: 0.09009326249361038
# Total weight diff: 574.147237, Max weight diff: 343.736603
# mse and l0 loss: 5827.310546875
# R_loss: 0.8355362415313721
# Average R_score: 0.16446372866630554
# gradient_norm: 0.10132645815610886
# Total weight diff: 532.843840, Max weight diff: 325.466492
# mse and l0 loss: 5769.82666015625
# R_loss: 0.5147258043289185
# Average R_score: 0.48527416586875916
# gradient_norm: 0.059285443276166916
# Total weight diff: 492.405372, Max weight diff: 301.851074
# mse and l0 loss: 6311.876953125
# R_loss: 0.5830446481704712
# Average R_score: 0.4169553220272064
# gradient_norm: 0.07967773079872131
# Total weight diff: 468.852562, Max weight diff: 287.615051
# mse and l0 loss: 6762.1845703125
# R_loss: 0.5955803394317627
# Average R_score: 0.4044196307659149
# gradient_norm: 0.06429646909236908
# Total weight diff: 456.919568, Max weight diff: 282.343201
# mse and l0 loss: 6405.935546875
# R_loss: 0.7185496687889099
# Average R_score: 0.2814503312110901
# gradient_norm: 0.08724753558635712
# Total weight diff: 433.608683, Max weight diff: 271.878265
# mse and l0 loss: 11961.30859375
# R_loss: 0.8293163776397705
# Average R_score: 0.17068363726139069
# gradient_norm: 0.09704110771417618
# Total weight diff: 566.910538, Max weight diff: 367.911499
# mse and l0 loss: 5968.923828125
# R_loss: 0.7623147368431091
# Average R_score: 0.23768526315689087
# gradient_norm: 0.09347673505544662
# ...
# Average R_score: 0.29259926080703735
# gradient_norm: 0.031892329454422
# Total weight diff: 599.611312, Max weight diff: 307.951965
# mse and l0 loss: 2788.9501953125
# R_loss: 0.5139960050582886
# Average R_score: 0.4860040247440338
# gradient_norm: 0.02473076991736889
# Total weight diff: 586.839326, Max weight diff: 307.168823
# mse and l0 loss: 2756.084716796875
# R_loss: 0.4382750988006592
# Average R_score: 0.5617249011993408
# gradient_norm: 0.024136340245604515
# Total weight diff: 559.448558, Max weight diff: 293.164551
# mse and l0 loss: 3825.72265625
# R_loss: 0.7590429782867432
# Average R_score: 0.24095699191093445
# gradient_norm: 0.030358178541064262
# Total weight diff: 758.770483, Max weight diff: 417.433228
# mse and l0 loss: 3258.99951171875
# R_loss: 0.6631250381469727
# Average R_score: 0.33687496185302734
# gradient_norm: 0.03607356175780296
# Total weight diff: 784.627444, Max weight diff: 433.459869
# mse and l0 loss: 3208.646484375
# R_loss: 0.5397495627403259
# Average R_score: 0.4602504372596741
# gradient_norm: 0.024977777153253555
# Total weight diff: 740.548955, Max weight diff: 409.675720
# mse and l0 loss: 3400.826416015625
# R_loss: 0.645283579826355
# Average R_score: 0.354716420173645
# gradient_norm: 0.029976123943924904
# Total weight diff: 778.703156, Max weight diff: 418.939575
# mse and l0 loss: 2892.971435546875
# R_loss: 0.6713163256645203
# Average R_score: 0.32868367433547974
# gradient_norm: 0.029729973524808884
# Total weight diff: 741.021509, Max weight diff: 390.354797
# mse and l0 loss: 3365.2841796875
# R_loss: 0.5085046291351318
# Average R_score: 0.49149540066719055
# gradient_norm: 0.030452817678451538
# Total weight diff: 763.052089, Max weight diff: 406.581329
# mse and l0 loss: 2879.4892578125
# R_loss: 0.5126327872276306
# Average R_score: 0.4873672127723694
# gradient_norm: 0.0256571676582098
# Total weight diff: 732.222029, Max weight diff: 383.779297
# mse and l0 loss: 3154.21875
# R_loss: 0.6756953001022339
# Average R_score: 0.3243047297000885
# gradient_norm: 0.030589623376727104
# Total weight diff: 715.779623, Max weight diff: 378.324066
# mse and l0 loss: 2941.36083984375
# R_loss: 0.4828900694847107
# Average R_score: 0.5171099305152893
# gradient_norm: 0.026551632210612297
# Total weight diff: 672.329432, Max weight diff: 354.370178
# mse and l0 loss: 3365.646728515625
# R_loss: 0.8324443697929382
# Average R_score: 0.16755564510822296
# gradient_norm: 0.042281895875930786
# Total weight diff: 645.984689, Max weight diff: 329.183380
# mse and l0 loss: 4624.62353515625
# R_loss: 0.7429560422897339
# Average R_score: 0.2570439279079437
# gradient_norm: 0.05987090989947319
# Total weight diff: 704.033727, Max weight diff: 379.853088
# mse and l0 loss: 2943.825439453125
# R_loss: 0.4850919842720032
# Average R_score: 0.5149080157279968
# gradient_norm: 0.024687236174941063
# Total weight diff: 665.668186, Max weight diff: 356.194763
# mse and l0 loss: 3447.90478515625
# R_loss: 0.6855372190475464
# Average R_score: 0.314462810754776
# gradient_norm: 0.036472633481025696
# Total weight diff: 660.542355, Max weight diff: 354.849976
# mse and l0 loss: 2870.962646484375
# R_loss: 0.4247032403945923
# Average R_score: 0.5752967596054077
# gradient_norm: 0.02180529572069645
# Total weight diff: 632.895995, Max weight diff: 335.253632
# mse and l0 loss: 3680.249755859375
# R_loss: 0.5693405270576477
# Average R_score: 0.4306594729423523
# gradient_norm: 0.03185917064547539
# Total weight diff: 607.586027, Max weight diff: 327.009644
# mse and l0 loss: 3233.15283203125
# R_loss: 0.441422700881958
# Average R_score: 0.558577299118042
# gradient_norm: 0.027377523481845856
# Total weight diff: 579.829536, Max weight diff: 311.163269
# mse and l0 loss: 3825.061767578125
# R_loss: 0.5198696851730347
# Average R_score: 0.48013028502464294
# gradient_norm: 0.028647856786847115
# Total weight diff: 571.744663, Max weight diff: 316.261719
# mse and l0 loss: 3376.526611328125
# R_loss: 0.6540796756744385
# Average R_score: 0.3459203541278839
# gradient_norm: 0.041368234902620316
# Total weight diff: 555.902326, Max weight diff: 300.954773
# mse and l0 loss: 3404.019287109375
# R_loss: 0.7870181798934937
# Average R_score: 0.21298179030418396
# gradient_norm: 0.035500191152095795
# Total weight diff: 535.690958, Max weight diff: 276.794678
# mse and l0 loss: 3537.076416015625
# R_loss: 0.5264362096786499
# Average R_score: 0.4735638201236725
# gradient_norm: 0.026814298704266548
# Total weight diff: 556.785859, Max weight diff: 293.946594
# mse and l0 loss: 3236.435546875
# R_loss: 0.6552478075027466
# Average R_score: 0.34475216269493103
# gradient_norm: 0.04210326820611954
# Total weight diff: 554.863560, Max weight diff: 291.331055
# mse and l0 loss: 3309.177490234375
# R_loss: 0.6855490803718567
# Average R_score: 0.3144509196281433
# gradient_norm: 0.03308670595288277
# Total weight diff: 560.601109, Max weight diff: 298.502472
# mse and l0 loss: 4821.73388671875
# R_loss: 0.7451612949371338
# Average R_score: 0.2548387348651886
# gradient_norm: 0.043145593255758286
# Total weight diff: 619.619353, Max weight diff: 333.246460
# mse and l0 loss: 3105.887939453125
# R_loss: 0.5399383306503296
# Average R_score: 0.4600616991519928
# gradient_norm: 0.027825986966490746
# Total weight diff: 608.823180, Max weight diff: 313.866028
# mse and l0 loss: 3327.0791015625
# R_loss: 0.5681470632553101
# Average R_score: 0.43185296654701233
# gradient_norm: 0.026212045922875404
# Total weight diff: 603.551905, Max weight diff: 309.858734
# mse and l0 loss: 4008.526123046875
# R_loss: 0.568710446357727
# Average R_score: 0.43128958344459534
# gradient_norm: 0.027696993201971054
# Total weight diff: 654.514357, Max weight diff: 352.280273
# mse and l0 loss: 3294.93408203125
# R_loss: 0.6130492687225342
# Average R_score: 0.3869507312774658
# gradient_norm: 0.030019545927643776
# Total weight diff: 716.904224, Max weight diff: 399.386993
# mse and l0 loss: 3234.365478515625
# R_loss: 0.543536901473999
# Average R_score: 0.4564630687236786
# gradient_norm: 0.0305266622453928
# Total weight diff: 692.117300, Max weight diff: 388.113647
# mse and l0 loss: 3857.0791015625
# R_loss: 0.6216591596603394
# Average R_score: 0.37834084033966064
# gradient_norm: 0.05665308237075806
# Total weight diff: 786.472008, Max weight diff: 437.608978
# mse and l0 loss: 3346.978759765625
# R_loss: 0.6669859290122986
# Average R_score: 0.3330140709877014
# gradient_norm: 0.034762319177389145
# Total weight diff: 741.975600, Max weight diff: 397.691559
# mse and l0 loss: 3900.51025390625
# R_loss: 0.7305598258972168
# Average R_score: 0.2694401443004608
# gradient_norm: 0.03600871190428734
# Total weight diff: 719.996883, Max weight diff: 383.871521
# mse and l0 loss: 3145.831298828125
# R_loss: 0.566382884979248
# Average R_score: 0.43361708521842957
# gradient_norm: 0.025560768321156502
# Total weight diff: 703.002865, Max weight diff: 375.243164
# mse and l0 loss: 3768.54296875
# R_loss: 0.4914228320121765
# Average R_score: 0.5085771679878235
# gradient_norm: 0.028687484562397003
# Total weight diff: 694.590424, Max weight diff: 380.567230
# mse and l0 loss: 3084.94775390625
# R_loss: 0.5864013433456421
# Average R_score: 0.4135986268520355
# gradient_norm: 0.02839755080640316
# Total weight diff: 656.899408, Max weight diff: 358.071411
# mse and l0 loss: 3366.82470703125
# R_loss: 0.7919484972953796
# Average R_score: 0.20805150270462036
# gradient_norm: 0.03388354554772377
# Total weight diff: 627.053002, Max weight diff: 334.976166
# mse and l0 loss: 3024.311767578125
# R_loss: 0.6669090986251831
# Average R_score: 0.3330909311771393
# gradient_norm: 0.03153768181800842
# Total weight diff: 596.607703, Max weight diff: 310.305054
# mse and l0 loss: 3391.21240234375
# R_loss: 0.6927412152290344
# Average R_score: 0.3072587847709656
# gradient_norm: 0.031331032514572144
# Total weight diff: 684.308319, Max weight diff: 366.132874
# mse and l0 loss: 3030.611572265625
# R_loss: 0.6277787685394287
# Average R_score: 0.3722212612628937
# gradient_norm: 0.033740922808647156
# Total weight diff: 692.800112, Max weight diff: 374.647888
# mse and l0 loss: 3103.709228515625
# R_loss: 0.5184506773948669
# Average R_score: 0.48154932260513306
# gradient_norm: 0.025367332622408867
# Total weight diff: 656.612723, Max weight diff: 359.476044
# mse and l0 loss: 3500.232666015625
# R_loss: 0.648760199546814
# Average R_score: 0.35123977065086365
# gradient_norm: 0.030160728842020035
# Total weight diff: 763.566008, Max weight diff: 392.922028
# mse and l0 loss: 3388.476318359375
# R_loss: 0.6940343976020813
# Average R_score: 0.3059656023979187
# gradient_norm: 0.03118760883808136
# Total weight diff: 737.038447, Max weight diff: 378.897034
# mse and l0 loss: 2908.1552734375
# R_loss: 0.4540024995803833
# Average R_score: 0.5459975004196167
# gradient_norm: 0.02167671173810959
# Total weight diff: 700.478221, Max weight diff: 355.301910
# mse and l0 loss: 3030.969482421875
# R_loss: 0.4513276219367981
# Average R_score: 0.5486723780632019
# gradient_norm: 0.022136151790618896
# Total weight diff: 671.861903, Max weight diff: 341.943237
# mse and l0 loss: 2825.607421875
# R_loss: 0.6849457025527954
# Average R_score: 0.315054327249527
# gradient_norm: 0.0347730778157711
# Total weight diff: 668.806103, Max weight diff: 345.611328
# mse and l0 loss: 2620.939697265625
# R_loss: 0.5961196422576904
# Average R_score: 0.40388035774230957
# gradient_norm: 0.029701219871640205
# Total weight diff: 635.295123, Max weight diff: 322.654297
# mse and l0 loss: 2810.86767578125
# R_loss: 0.5890316367149353
# Average R_score: 0.4109683632850647
# gradient_norm: 0.028671739622950554
# Total weight diff: 599.913867, Max weight diff: 300.242004
# mse and l0 loss: 4562.7685546875
# R_loss: 0.7762797474861145
# Average R_score: 0.2237202674150467
# gradient_norm: 0.04024789109826088
# Total weight diff: 736.451586, Max weight diff: 380.705597
# mse and l0 loss: 2864.41650390625
# R_loss: 0.7015951871871948
# Average R_score: 0.2984048128128052
# gradient_norm: 0.03835767135024071
# Total weight diff: 693.344114, Max weight diff: 353.486511
# mse and l0 loss: 3018.177001953125
# R_loss: 0.6702001094818115
# Average R_score: 0.3297998607158661
# gradient_norm: 0.032829444855451584
# Total weight diff: 652.886885, Max weight diff: 328.003357
# mse and l0 loss: 4669.59716796875
# R_loss: 0.49616366624832153
# Average R_score: 0.5038363337516785
# gradient_norm: 0.02794233150780201
# Total weight diff: 1163.117345, Max weight diff: 702.811096
# mse and l0 loss: 2899.91748046875
# R_loss: 0.4590414762496948
# Average R_score: 0.5409585237503052
# gradient_norm: 0.02767890878021717
# Total weight diff: 1074.177980, Max weight diff: 644.678162
# mse and l0 loss: 2944.44873046875
# R_loss: 0.7183020114898682
# Average R_score: 0.28169798851013184
# gradient_norm: 0.036884550005197525
# Total weight diff: 997.091547, Max weight diff: 581.080688
# mse and l0 loss: 3468.93896484375
# R_loss: 0.5697479248046875
# Average R_score: 0.4302521049976349
# gradient_norm: 0.031623486429452896
# Total weight diff: 949.913633, Max weight diff: 518.674438
# mse and l0 loss: 2742.898681640625
# R_loss: 0.6946330070495605
# Average R_score: 0.30536696314811707
# gradient_norm: 0.035627759993076324
# Total weight diff: 888.531419, Max weight diff: 482.157532
# mse and l0 loss: 3373.933837890625
# R_loss: 0.7443739771842957
# Average R_score: 0.25562602281570435
# gradient_norm: 0.032944221049547195
# Total weight diff: 841.642006, Max weight diff: 446.322205
# mse and l0 loss: 3028.485595703125
# R_loss: 0.6510323286056519
# Average R_score: 0.34896767139434814
# gradient_norm: 0.030498849228024483
# Total weight diff: 791.766698, Max weight diff: 414.310699
# mse and l0 loss: 2995.68017578125
# R_loss: 0.48099052906036377
# Average R_score: 0.5190094709396362
# gradient_norm: 0.022893249988555908
# Total weight diff: 736.849755, Max weight diff: 386.227417
# mse and l0 loss: 4832.939453125
# R_loss: 0.7422963380813599
# Average R_score: 0.2577036917209625
# gradient_norm: 0.033085573464632034
# Total weight diff: 787.685065, Max weight diff: 424.160278
# mse and l0 loss: 3345.088623046875
# R_loss: 0.6962867975234985
# Average R_score: 0.3037131726741791
# gradient_norm: 0.03601257503032684
# Total weight diff: 768.901047, Max weight diff: 398.416626
# mse and l0 loss: 3269.666015625
# R_loss: 0.7757850885391235
# Average R_score: 0.22421494126319885
# gradient_norm: 0.037625983357429504
# Total weight diff: 732.986341, Max weight diff: 373.813660
# mse and l0 loss: 3666.152099609375
# R_loss: 0.6640671491622925
# Average R_score: 0.3359328508377075
# gradient_norm: 0.035967469215393066
# Total weight diff: 722.684638, Max weight diff: 378.408569
# mse and l0 loss: 3567.881591796875
# R_loss: 0.7424600124359131
# Average R_score: 0.2575399875640869
# gradient_norm: 0.041138485074043274
# Total weight diff: 730.410053, Max weight diff: 389.946899
# mse and l0 loss: 2979.22216796875
# R_loss: 0.6562922596931458
# Average R_score: 0.34370774030685425
# gradient_norm: 0.036344632506370544
# Total weight diff: 686.209295, Max weight diff: 357.447510
# mse and l0 loss: 2781.070556640625
# R_loss: 0.4623568654060364
# Average R_score: 0.5376431345939636
# gradient_norm: 0.021604858338832855
# Total weight diff: 648.283674, Max weight diff: 336.117889
# mse and l0 loss: 2753.7041015625
# R_loss: 0.6705831289291382
# Average R_score: 0.3294168710708618
# gradient_norm: 0.03388208523392677
# Total weight diff: 614.781728, Max weight diff: 314.556458
# mse and l0 loss: 2900.44677734375
# R_loss: 0.698878288269043
# Average R_score: 0.30112168192863464
# gradient_norm: 0.0443873330950737
# Total weight diff: 587.544871, Max weight diff: 300.063568
# mse and l0 loss: 3413.351318359375
# R_loss: 0.4093008041381836
# Average R_score: 0.5906991958618164
# gradient_norm: 0.02435045689344406
# Total weight diff: 561.143096, Max weight diff: 293.471252
# mse and l0 loss: 2896.014404296875
# R_loss: 0.5241824388504028
# Average R_score: 0.47581759095191956
# gradient_norm: 0.032136593014001846
# Total weight diff: 529.227285, Max weight diff: 277.125702
# mse and l0 loss: 2671.652099609375
# R_loss: 0.47303861379623413
# Average R_score: 0.5269613862037659
# gradient_norm: 0.021996140480041504
# Total weight diff: 501.289020, Max weight diff: 258.650757
# mse and l0 loss: 3092.03515625
# R_loss: 0.6472113132476807
# Average R_score: 0.35278868675231934
# gradient_norm: 0.032528746873140335
# Total weight diff: 480.191588, Max weight diff: 244.405670
# mse and l0 loss: 3346.253173828125
# R_loss: 0.7634145021438599
# Average R_score: 0.23658549785614014
# gradient_norm: 0.043507497757673264
# Total weight diff: 513.186643, Max weight diff: 267.152191
# mse and l0 loss: 2813.869140625
# R_loss: 0.4631945490837097
# Average R_score: 0.5368054509162903
# gradient_norm: 0.025809263810515404
# Total weight diff: 511.973935, Max weight diff: 268.042023
# mse and l0 loss: 4055.60693359375
# R_loss: 0.5421370267868042
# Average R_score: 0.4578629732131958
# gradient_norm: 0.024313315749168396
# Total weight diff: 518.758701, Max weight diff: 275.372742
# mse and l0 loss: 2855.354736328125
# R_loss: 0.750140368938446
# Average R_score: 0.24985964596271515
# gradient_norm: 0.0400811992585659
# Total weight diff: 523.160863, Max weight diff: 272.332336
# mse and l0 loss: 2689.86572265625
# R_loss: 0.6861288547515869
# Average R_score: 0.3138711452484131
# gradient_norm: 0.0329134576022625
# Total weight diff: 513.441154, Max weight diff: 260.832581
# mse and l0 loss: 2886.5263671875
# R_loss: 0.7531760334968567
# Average R_score: 0.2468239665031433
# gradient_norm: 0.03906743973493576
# Total weight diff: 513.274261, Max weight diff: 263.033813
# mse and l0 loss: 2627.26220703125
# R_loss: 0.5349408388137817
# Average R_score: 0.4650591313838959
# gradient_norm: 0.02650238759815693
# Total weight diff: 504.137196, Max weight diff: 257.254211
# mse and l0 loss: 4089.790771484375
# R_loss: 0.5908143520355225
# Average R_score: 0.40918561816215515
# gradient_norm: 0.0284345094114542
# Total weight diff: 626.395210, Max weight diff: 323.761963
# mse and l0 loss: 3337.586181640625
# R_loss: 0.5282212495803833
# Average R_score: 0.4717787504196167
# gradient_norm: 0.031247742474079132
# Total weight diff: 600.115103, Max weight diff: 311.262878
# mse and l0 loss: 3446.793701171875
# R_loss: 0.511176586151123
# Average R_score: 0.48882338404655457
# gradient_norm: 0.024244440719485283
# Total weight diff: 577.628630, Max weight diff: 301.187683
# mse and l0 loss: 3326.708251953125
# R_loss: 0.5816609859466553
# Average R_score: 0.41833898425102234
# gradient_norm: 0.02871294505894184
