# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]= "6,7"
import torch
from tqdm import tqdm
import plotly.express as px

torch.set_grad_enabled(False);

# %%
from transformer_lens import HookedTransformer
from sae_lens import SAE

# Choose a layer you want to focus on
device= "cuda:0"
model = HookedTransformer.from_pretrained("gpt2-small").to('cuda')

# Initialize SAE
layer = 8
sae, cfg_dict, _ = SAE.from_pretrained(
    release="gpt2-small-res-jb",
    sae_id=f"blocks.{layer}.hook_resid_pre",
    device= "cuda:0"
)

# get hook point
hook_point = sae.cfg.hook_name
print(hook_point)
# Out:
# Loaded pretrained model gpt2-small into HookedTransformer
# Moving model to device:  cuda
# blocks.8.hook_resid_pre

# %%
from sae_lens import SAETrainingRunner, LanguageModelSAERunnerConfig, SAE
from sae_lens.training.training_sae import TrainingSAE
import torch
from typing import Any, Tuple, cast
from transformer_lens import HookedTransformer
from typing import Optional
from datasets import Dataset, IterableDataset
from datasets import load_dataset
import os
import torch.nn.functional as F
import wandb

class RSAETrainingRunner(SAETrainingRunner):
    def __init__(
        self,
        cfg: LanguageModelSAERunnerConfig,
        r_weight: float = 1,
        n_steps: int = 50,
        k: int = 7,
    ):
        super().__init__(cfg)
        self.r_weight = r_weight
        self.n_steps = n_steps
        self.k = k
        self.tokens_processed = 0
        self.dataset_iterator: Optional[Iterator] = None
        self.dataset: Optional[Dataset | IterableDataset] = None
        self.optimizer = torch.optim.Adam(self.sae.parameters(), lr=self.cfg.lr)
        self.step = 0

    def run(self):
        if self.cfg.log_to_wandb:
            wandb.init(
                project=self.cfg.wandb_project,
                config=cast(Any, self.cfg),
                name=self.cfg.run_name,
                id=self.cfg.wandb_id,
            )

        self._compile_if_needed()

        try:
            # Main training loop
            while self.tokens_processed < self.cfg.training_tokens:
                batch = self.get_next_batch()
                loss_dict = self.training_step(batch)
                
                # Update tokens processed
                self.tokens_processed += batch.numel()
                
                # Log metrics
                if self.cfg.log_to_wandb and self.step % self.cfg.wandb_log_frequency == 0:
                    wandb.log({**loss_dict, "tokens_processed": self.tokens_processed}, step=self.step)

                self.step += 1

        except KeyboardInterrupt:
            print("Training interrupted. Saving checkpoint...")
            self.save_checkpoint(self.step)

        if self.cfg.log_to_wandb:
            wandb.finish()

        return self.sae

    def setup_dataset(self):
        if self.cfg.is_dataset_tokenized:
            self.dataset = load_dataset(self.cfg.dataset_path, streaming=self.cfg.streaming, split="train")
        else:
            # If the dataset is not tokenized, we need to tokenize it
            raw_dataset = load_dataset(self.cfg.dataset_path, streaming=self.cfg.streaming, split="train")
            self.dataset = raw_dataset.map(lambda examples: self.model.tokenizer(examples['text'], truncation=True, padding='max_length', max_length=self.cfg.context_size), batched=True)
        
        self.dataset_iterator = iter(self.dataset)

    def check_weight_updates(self):
        if not hasattr(self, 'old_weights'):
            self.old_weights = {name: param.clone().detach() for name, param in self.sae.named_parameters()}
            return

        total_diff = 0
        max_diff = 0
        for name, param in self.sae.named_parameters():
            diff = (param.data - self.old_weights[name]).abs().sum().item()
            total_diff += diff
            max_diff = max(max_diff, diff)
            self.old_weights[name] = param.clone().detach()
        
        print(f"Total weight diff: {total_diff:.6f}, Max weight diff: {max_diff:.6f}")
        #wandb.log({"total_weight_diff": total_diff, "max_weight_diff": max_diff}, step=self.step)

    def get_next_batch(self) -> torch.Tensor:
        if self.dataset_iterator is None:
            self.setup_dataset()
        
        batch_size = self.cfg.train_batch_size_tokens // self.cfg.context_size
        batch = []

        while len(batch) < batch_size:
            try:
                item = next(self.dataset_iterator)
                if self.cfg.is_dataset_tokenized:
                    input_ids = torch.tensor(item['input_ids'], dtype=torch.long)
                else:
                    input_ids = torch.tensor(item['input_ids'], dtype=torch.long)
                
                # Ensure the sequence is the correct length
                if input_ids.size(0) < self.cfg.context_size:
                    input_ids = torch.cat([input_ids, torch.zeros(self.cfg.context_size - input_ids.size(0), dtype=torch.long)])
                elif input_ids.size(0) > self.cfg.context_size:
                    input_ids = input_ids[:self.cfg.context_size]
                
                batch.append(input_ids)

            except StopIteration:
                # If we've reached the end of the dataset, reset the iterator
                self.dataset_iterator = iter(self.dataset)
                # If we couldn't fill the batch, break and return what we have
                if len(batch) > 0:
                    break
                else:
                    continue  # If the batch is empty, try again with the reset iterator

        # Stack the batch items into a single tensor
        batch_tensor = torch.stack(batch)

        return batch_tensor.to(self.cfg.device)

    def training_step(self, input_ids: torch.Tensor) -> dict[str, float]:
        # Compute activations and integrated gradients
        activations, attributions = self.integrated_gradients(
            self.model,
            input_ids,
            self.cfg.hook_name,
            self.n_steps,
            largest_logit=False
        )

        with torch.enable_grad():
            # Compute R score for each token in the sequence
            r_scores = []
            for i in range(activations.shape[1]): 
                 # Iterate over sequence length
                r_score = self.compute_r_score(
                    self.sae,
                    activations[:, i],
                    attributions[:, i],
                    self.k
                )
            
                r_scores.append(r_score)
            
            if i % 5 == 0:
                self.check_weight_updates()
            avg_r_score = sum(r_scores) / len(r_scores)
            sae_output = self.sae.training_forward_pass(activations, self.cfg.l1_coefficient)
            r_loss = 1 - avg_r_score
            print(f"mse and l0 loss: {sae_output.loss}")
            print(f"R_loss: {r_loss}")
            print(f"Average R_score: {avg_r_score}")
            total_loss = r_loss + (sae_output.loss / 800000)

        # Perform optimization step
        self.optimizer.zero_grad()
        total_loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.sae.parameters(), max_norm=float('inf'))
        print(f"gradient_norm: {grad_norm}")
        #wandb.log({"gradient_norm": grad_norm}, step=self.step)
        self.optimizer.step()

        # Create a dictionary for logging
        loss_dict = {
            'mse_loss': sae_output.mse_loss,
            'l1_loss': sae_output.l1_loss,
            'ghost_grad_loss': sae_output.ghost_grad_loss,
            'auxiliary_reconstruction_loss': sae_output.auxiliary_reconstruction_loss,
            'r_score': avg_r_score,
            'total_loss': total_loss.item()
        }
        return loss_dict


    def compute_r_score(
        self,
        sae: SAE,
        activation: torch.Tensor,
        attribution: torch.Tensor,
        k: int = 5
    ) -> torch.Tensor:
        """
        Compute the R-score for multiple sets of vectors and attributions.
        
        Args:
        sae_directions: Tensor of shape [batch_size, num_vectors, vector_dim]
        attribution: Tensor of shape [batch_size, vector_dim]
        top_k_values: Tensor of shape [batch_size, num_vectors]
        epsilon: Small value to avoid division by zero
        
        Returns:
        r_scores: Tensor of shape [batch_size]
        """
        epsilon: float = 1e-8
        sae_directions, top_k_values = self.get_top_k_active_directions(sae, activation, k)
        sae_directions = sae_directions.permute(2, 1, 0)

        #print(f"attribtion: {attribution.shape}")
        #print(f"sae_directions: {sae_directions.shape}")

        # Compute the projection matrix
        V = sae_directions.transpose(1, 2)  # [batch_size, vector_dim, num_vectors]
        VTV = torch.bmm(V.transpose(1, 2), V)  # [batch_size, num_vectors, num_vectors]
        VTV_inv = torch.inverse(VTV + epsilon * torch.eye(VTV.size(1), device=VTV.device).unsqueeze(0))
        P = torch.bmm(torch.bmm(V, VTV_inv), V.transpose(1, 2))  # [batch_size, vector_dim, vector_dim]
        
        # Compute the projection of attribution onto the span of weighted directions
        u = attribution.unsqueeze(-1)  # [batch_size, vector_dim, 1]
        proj_u = torch.bmm(P, u)  # [batch_size, vector_dim, 1]
        
        
        # Compute the R-score
        r_scores = torch.sqrt(
            (torch.bmm(u.transpose(1, 2), proj_u).squeeze(-1) + epsilon) /
            (torch.sum(u**2, dim=1) + epsilon)
        ).squeeze(-1)
        #print(f"r_scores {r_scores}")
        return r_scores.mean()

    def integrated_gradients(
        self,
        model: HookedTransformer,
        input_ids: torch.Tensor,
        target_layer: str,
        n_steps: int = 30,
        largest_logit: bool = False,
    ) -> Tuple[torch.Tensor, torch.Tensor]:
        device = input_ids.device
        layer_index = int(target_layer.split('.')[1])

        # Get baseline and input activations
        with torch.no_grad():
            _, cache = model.run_with_cache(input_ids)
            input_activation = cache[target_layer]
        
        baseline_activation = torch.zeros_like(input_activation)
        delta = (input_activation - baseline_activation) / n_steps
        integrated_gradients = torch.zeros_like(input_activation)

        for i in range(n_steps + 1):
            with torch.enable_grad():
                with torch.autograd.set_detect_anomaly(True):
                    interpolated_activation = baseline_activation + i * delta
                    interpolated_activation.requires_grad_(True)
                    logits = self.compute_subsequent_outputs_logits_only(model, interpolated_activation, layer_index)

                    if largest_logit:
                        last_token_logits = logits[:, -1]
                        max_logit_value, max_logit_index = torch.max(last_token_logits, dim=-1)
                        
                        # Compute gradient only for the highest logit
                        max_logit_value.sum().backward(retain_graph=True)
                        gradient = interpolated_activation.grad

                        integrated_gradients += gradient / n_steps
                        interpolated_activation.grad = None  
                    else:
                        loss = logits[:, -1, input_ids[:, -1]].sum()
                        loss.backward(create_graph=False)
                        gradient = interpolated_activation.grad

                        integrated_gradients += gradient / n_steps

        attributions = integrated_gradients * (input_activation - baseline_activation)
        return input_activation, attributions

    
    def get_top_k_active_directions(self, sae: SAE, activation: torch.Tensor, k: int):
        # Assuming activation shape is [16, 768]
        latent = sae.encode(activation)  # [16, n_features]
        top_k_values, top_k_indices = torch.topk(latent.abs(), k, dim=-1)  # Both: [16, 5]
        
        # Gather top k directions for each item in the batch
        top_k_directions = sae.W_enc[:, top_k_indices.flatten()].view(sae.W_enc.shape[0], k, -1)  # [768, 5, 16]
        
        return top_k_directions, top_k_values

    def compute_subsequent_outputs_logits_only(self, model: torch.nn.Module, activation: torch.Tensor, layer_index: int) -> torch.Tensor:
        # Ensure activation requires gradients
        with torch.enable_grad():
            if not activation.requires_grad:
                activation.requires_grad_(True)
            if activation.ndim == 2:
                activation = activation.unsqueeze(1)       
            current_activation = activation
            for block in model.blocks[layer_index+1:]:
                current_activation = block(current_activation)
                
            current_activation = model.ln_final(current_activation)
            logits = model.unembed(current_activation)
        return logits
    



cfg = LanguageModelSAERunnerConfig(
    # Model and SAE Configuration
    model_name="gpt2-small",
    hook_name="blocks.8.hook_resid_pre",
    hook_layer=8,
    d_in=768,
    expansion_factor=32,

    # Dataset Configuration
    dataset_path="apollo-research/Skylion007-openwebtext-tokenizer-gpt2",
    is_dataset_tokenized=True,
    streaming=True,

    # Training Parameters
    train_batch_size_tokens=400,
    context_size=256,
    training_tokens=10_000_000,  # 10 million tokens for finetuning
    lr=5e-3,  # Lower learning rate for finetuning
    lr_scheduler_name="cosine",
    l1_coefficient=5e-3,
    lp_norm=1.0,

    # Logging and Checkpointing
    log_to_wandb=True,
    wandb_project="sae_finetuning_r_score",
    n_checkpoints=5,
    checkpoint_path="./checkpoints",

    # Hardware Configuration
    device="cuda",
    dtype="float32",
)
os.environ["CUDA_VISIBLE_DEVICES"]= "4,5,6,7"
pretrained_sae, original_cfg_dict, sparsity = SAE.from_pretrained(
    release="gpt2-small-res-jb",
    sae_id="blocks.8.hook_resid_pre",
    device="cuda:0",
)
# Initialize the runner with the pretrained SAE
runner = RSAETrainingRunner(cfg, pretrained_sae, n_steps=30, k=7)
# Out:
# Run name: 24576-L1-0.005-LR-0.005-Tokens-1.000e+07
# n_tokens_per_buffer (millions): 0.16384
# Lower bound: n_contexts_per_buffer (millions): 0.00064
# Total training steps: 25000
# Total wandb updates: 2500
# n_tokens_per_feature_sampling_window (millions): 204.8
# n_tokens_per_dead_feature_window (millions): 102.4
# We will reset the sparsity calculation 12 times.
# Number tokens in sparsity calculation window: 8.00e+05
# Loaded pretrained model gpt2-small into HookedTransformer
# Resolving data files:   0%|          | 0/73 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/73 [00:00<?, ?it/s]
# Objective value: 7284788.0000:   2%|▏         | 2/100 [00:00<00:00, 209.66it/s]

# %%
import os
import json
import torch
import wandb
from sae_lens import SAE

def save_finetuned_sae(sae: SAE, config: dict, step: int, save_path: str, log_to_wandb: bool = True):
    # Create the save directory
    checkpoint_path = os.path.join(save_path, f"finetuned_sae_step_{step}")
    os.makedirs(checkpoint_path, exist_ok=True)
    
    # Save the SAE locally
    sae.save_model(checkpoint_path)
    
    # Save the configuration
    config_path = os.path.join(checkpoint_path, "config.json")
    with open(config_path, "w") as f:
        json.dump(config, f)
    
    print(f"Finetuned SAE saved locally to: {checkpoint_path}")
    
    # Log to wandb if enabled
    if log_to_wandb:
        # Initialize wandb if it's not already running
        if wandb.run is None:
            wandb.init(project="ae_finetuning_r_score")
        
        # Create a wandb Artifact
        artifact = wandb.Artifact(
            name=f"finetuned_sae_step_{step}",
            type="model",
            description="Finetuned Sparse Autoencoder",
            metadata=config
        )
        
        # Add files to the artifact
        artifact.add_file(os.path.join(checkpoint_path, "SAE_WEIGHTS_PATH"))
        artifact.add_file(os.path.join(checkpoint_path, "SAE_CFG_PATH"))
        artifact.add_file(config_path)
        
        # Log the artifact to wandb
        wandb.log_artifact(artifact)
        
        print(f"Finetuned SAE logged to wandb as artifact: {artifact.name}")

# %%
import wandb
finetuned_sae = runner.run()

save_finetuned_sae(
    sae=finetuned_sae,
    config=runner.cfg.to_dict(),
    step=runner.step,
    save_path="./checkpoints",
    log_to_wandb=True
)
# Out:
# wandb version 0.17.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/mnt/pccfs2/backed_up/jeffolmo/sae_functional_significance/wandb/run-20240716_173352-3dbqd35u</code>
# Syncing run <strong><a href='https://wandb.ai/jeffreyjolmo-byu/sae_finetuning_r_score/runs/3dbqd35u' target="_blank">24576-L1-0.005-LR-0.005-Tokens-1.000e+07</a></strong> to <a href='https://wandb.ai/jeffreyjolmo-byu/sae_finetuning_r_score' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/jeffreyjolmo-byu/sae_finetuning_r_score' target="_blank">https://wandb.ai/jeffreyjolmo-byu/sae_finetuning_r_score</a>
#  View run at <a href='https://wandb.ai/jeffreyjolmo-byu/sae_finetuning_r_score/runs/3dbqd35u' target="_blank">https://wandb.ai/jeffreyjolmo-byu/sae_finetuning_r_score/runs/3dbqd35u</a>
# Resolving data files:   0%|          | 0/73 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/73 [00:00<?, ?it/s]
# mse and l0 loss: 85418.8515625
# R_loss: 0.9062745571136475
# Average R_score: 0.09372545778751373
# gradient_norm: 0.6121602058410645
# Total weight diff: 186176.226668, Max weight diff: 93280.453125
# mse and l0 loss: 9503695.0
# R_loss: 0.9079520106315613
# Average R_score: 0.09204798936843872
# gradient_norm: 17.791101455688477
# Total weight diff: 130041.577149, Max weight diff: 68210.812500
# mse and l0 loss: 259743.140625
# R_loss: 0.9051637053489685
# Average R_score: 0.0948362722992897
# gradient_norm: 0.9893543124198914
# Total weight diff: 104796.920078, Max weight diff: 52589.210938
# mse and l0 loss: 735669.6875
# R_loss: 0.9033849239349365
# Average R_score: 0.09661506116390228
# gradient_norm: 2.7058353424072266
# Total weight diff: 78044.481183, Max weight diff: 43656.484375
# mse and l0 loss: 1044603.3125
# R_loss: 0.9098259806632996
# Average R_score: 0.09017402678728104
# gradient_norm: 1.4878594875335693
# Total weight diff: 73737.491240, Max weight diff: 38093.335938
# mse and l0 loss: 395614.0
# R_loss: 0.8999232053756714
# Average R_score: 0.10007677972316742
# gradient_norm: 0.4388592839241028
# Total weight diff: 65231.972655, Max weight diff: 32594.652344
# mse and l0 loss: 261465.125
# R_loss: 0.9022684097290039
# Average R_score: 0.0977315902709961
# gradient_norm: 0.413504034280777
# Total weight diff: 57623.796739, Max weight diff: 28803.189453
# mse and l0 loss: 399533.875
# R_loss: 0.9037797451019287
# Average R_score: 0.0962202399969101
# gradient_norm: 0.49323299527168274
# Total weight diff: 48338.975899, Max weight diff: 26596.093750
# mse and l0 loss: 1337475.875
# R_loss: 0.8958470821380615
# Average R_score: 0.10415289551019669
# gradient_norm: 1.2151191234588623
# Total weight diff: 46463.223552, Max weight diff: 27856.363281
# mse and l0 loss: 2593095.0
# R_loss: 0.9055521488189697
# Average R_score: 0.09444783627986908
# gradient_norm: 1.8760559558868408
# Total weight diff: 59365.858626, Max weight diff: 30025.265625
# mse and l0 loss: 1384638.5
# R_loss: 0.8932366967201233
# Average R_score: 0.1067633256316185
# gradient_norm: 1.4595340490341187
# Total weight diff: 49066.168237, Max weight diff: 25897.939453
# mse and l0 loss: 717102.4375
# R_loss: 0.8834671974182129
# Average R_score: 0.1165328323841095
# gradient_norm: 1.0279196500778198
# Total weight diff: 43247.916379, Max weight diff: 24118.775391
# mse and l0 loss: 2927611.5
# R_loss: 0.897025465965271
# Average R_score: 0.1029745414853096
# gradient_norm: 2.9792206287384033
# Total weight diff: 40715.605082, Max weight diff: 24749.687500
# mse and l0 loss: 1635593.125
# R_loss: 0.896190881729126
# Average R_score: 0.10380914062261581
# gradient_norm: 1.8625600337982178
# Total weight diff: 37120.579883, Max weight diff: 22860.902344
# mse and l0 loss: 1534009.375
# R_loss: 0.8947157859802246
# Average R_score: 0.1052841916680336
# gradient_norm: 1.519512414932251
# Total weight diff: 37786.666264, Max weight diff: 21392.820312
# mse and l0 loss: 852185.6875
# R_loss: 0.8948091268539429
# Average R_score: 0.10519087314605713
# gradient_norm: 0.7898906469345093
# Total weight diff: 39179.107945, Max weight diff: 20095.271484
# mse and l0 loss: 850668.5
# R_loss: 0.8759579062461853
# Average R_score: 0.1240420788526535
# gradient_norm: 0.8567559719085693
# Total weight diff: 37677.387661, Max weight diff: 18883.550781
# mse and l0 loss: 561114.8125
# R_loss: 0.8706843852996826
# Average R_score: 0.12931561470031738
# gradient_norm: 0.728334367275238
# Total weight diff: 35204.618004, Max weight diff: 17744.738281
# mse and l0 loss: 1407055.0
# R_loss: 0.8884479999542236
# Average R_score: 0.11155197769403458
# gradient_norm: 1.2109431028366089
# Total weight diff: 32748.919770, Max weight diff: 17572.072266
# mse and l0 loss: 1158800.125
# R_loss: 0.8464100360870361
# Average R_score: 0.15358997881412506
# gradient_norm: 0.7692441344261169
# Total weight diff: 31381.019981, Max weight diff: 17298.347656
# mse and l0 loss: 804558.875
# R_loss: 0.9058084487915039
# Average R_score: 0.0941915288567543
# gradient_norm: 0.663921594619751
# Total weight diff: 30816.816785, Max weight diff: 16441.347656
# mse and l0 loss: 268166.90625
# R_loss: 0.8511512279510498
# Average R_score: 0.14884880185127258
# gradient_norm: 0.2914661765098572
# Total weight diff: 28400.107286, Max weight diff: 14967.681641
# mse and l0 loss: 398274.46875
# R_loss: 0.8598924279212952
# Average R_score: 0.14010755717754364
# gradient_norm: 0.3890800476074219
# Total weight diff: 26726.534240, Max weight diff: 14093.976562
# mse and l0 loss: 872541.4375
# R_loss: 0.8512680530548096
# Average R_score: 0.14873193204402924
# gradient_norm: 0.717308521270752
# Total weight diff: 28491.662299, Max weight diff: 14272.481445
# mse and l0 loss: 1397083.25
# R_loss: 0.8952926397323608
# Average R_score: 0.10470737516880035
# gradient_norm: 1.6042466163635254
# Total weight diff: 28694.819071, Max weight diff: 15962.759766
# mse and l0 loss: 594358.0
# R_loss: 0.8232256174087524
# Average R_score: 0.17677439749240875
# gradient_norm: 0.5871501564979553
# Total weight diff: 27693.275378, Max weight diff: 15493.583008
# mse and l0 loss: 308173.125
# R_loss: 0.8999053239822388
# Average R_score: 0.10009469091892242
# gradient_norm: 0.3416552245616913
# Total weight diff: 25824.972212, Max weight diff: 14517.562500
# mse and l0 loss: 1323336.875
# R_loss: 0.9029312133789062
# Average R_score: 0.09706878662109375
# gradient_norm: 0.9128764867782593
# Total weight diff: 30342.387797, Max weight diff: 15861.253906
# mse and l0 loss: 126347.3359375
# R_loss: 0.8834609985351562
# Average R_score: 0.11653899401426315
# gradient_norm: 0.20040827989578247
# Total weight diff: 27565.018123, Max weight diff: 14281.042969
# mse and l0 loss: 142196.140625
# R_loss: 0.8175063729286194
# Average R_score: 0.18249362707138062
# gradient_norm: 0.23073263466358185
# Total weight diff: 24940.374166, Max weight diff: 12789.081055
# mse and l0 loss: 1500171.25
# R_loss: 0.8560941815376282
# Average R_score: 0.14390581846237183
# gradient_norm: 1.0487926006317139
# Total weight diff: 21936.771086, Max weight diff: 12961.364258
# mse and l0 loss: 1266879.0
# R_loss: 0.8942360877990723
# Average R_score: 0.10576393455266953
# gradient_norm: 0.9263026118278503
# Total weight diff: 23025.156568, Max weight diff: 12797.650391
# mse and l0 loss: 579104.875
# R_loss: 0.8849732875823975
# Average R_score: 0.11502670496702194
# gradient_norm: 0.4557546377182007
# Total weight diff: 23158.935819, Max weight diff: 12135.605469
# mse and l0 loss: 2983047.25
# R_loss: 0.853524923324585
# Average R_score: 0.14647504687309265
# gradient_norm: 2.9175689220428467
# Total weight diff: 44012.422146, Max weight diff: 22362.871094
# mse and l0 loss: 244001.234375
# R_loss: 0.8926037549972534
# Average R_score: 0.10739623755216599
# gradient_norm: 0.2537570595741272
# Total weight diff: 39300.389985, Max weight diff: 19761.550781
# mse and l0 loss: 945396.8125
# R_loss: 0.8417162299156189
# Average R_score: 0.1582837849855423
# gradient_norm: 1.0605757236480713
# Total weight diff: 35295.785462, Max weight diff: 19006.429688
# mse and l0 loss: 4665575.5
# R_loss: 0.8819003105163574
# Average R_score: 0.11809966713190079
# gradient_norm: 5.372241497039795
# Total weight diff: 48196.820716, Max weight diff: 28131.164062
# mse and l0 loss: 425664.0
# R_loss: 0.7970044612884521
# Average R_score: 0.20299550890922546
# gradient_norm: 0.37183770537376404
# Total weight diff: 43765.840208, Max weight diff: 25674.556641
# mse and l0 loss: 1167927.0
# R_loss: 0.8137128353118896
# Average R_score: 0.18628716468811035
# gradient_norm: 0.9254967570304871
# Total weight diff: 41384.551275, Max weight diff: 23639.451172
# mse and l0 loss: 693040.625
# R_loss: 0.8099468350410461
# Average R_score: 0.19005316495895386
# gradient_norm: 0.5595337152481079
# Total weight diff: 38694.942904, Max weight diff: 21765.683594
# mse and l0 loss: 646648.5
# R_loss: 0.8095144629478455
# Average R_score: 0.19048553705215454
# gradient_norm: 0.5056073069572449
# Total weight diff: 35080.879846, Max weight diff: 20434.269531
# mse and l0 loss: 756852.125
# R_loss: 0.8767912983894348
# Average R_score: 0.12320870906114578
# gradient_norm: 0.537625253200531
# Total weight diff: 32629.162044, Max weight diff: 19222.382812
# mse and l0 loss: 865148.25
# R_loss: 0.769922137260437
# Average R_score: 0.230077862739563
# gradient_norm: 0.6928198337554932
# Total weight diff: 31561.004182, Max weight diff: 18697.410156
# mse and l0 loss: 285634.75
# R_loss: 0.8556079864501953
# Average R_score: 0.1443919837474823
# gradient_norm: 0.25977811217308044
# Total weight diff: 29019.921978, Max weight diff: 17177.226562
# mse and l0 loss: 465784.34375
# R_loss: 0.8119329810142517
# Average R_score: 0.1880670189857483
# gradient_norm: 0.4031883478164673
# Total weight diff: 27297.617151, Max weight diff: 15994.640625
# mse and l0 loss: 515957.625
# R_loss: 0.8013536334037781
# Average R_score: 0.19864638149738312
# gradient_norm: 0.4562828838825226
# Total weight diff: 25007.449150, Max weight diff: 14937.246094
# mse and l0 loss: 314994.40625
# R_loss: 0.8954790830612183
# Average R_score: 0.10452088713645935
# gradient_norm: 0.33168405294418335
# Total weight diff: 23348.938838, Max weight diff: 14067.096680
# mse and l0 loss: 582098.875
# R_loss: 0.7646998167037964
# Average R_score: 0.235300213098526
# gradient_norm: 0.46014901995658875
# Total weight diff: 21604.184230, Max weight diff: 13230.649414
# mse and l0 loss: 862993.6875
# R_loss: 0.8719522953033447
# Average R_score: 0.12804767489433289
# gradient_norm: 0.73097163438797
# Total weight diff: 23261.267783, Max weight diff: 13462.450195
# mse and l0 loss: 228828.984375
# R_loss: 0.8678046464920044
# Average R_score: 0.1321953535079956
# gradient_norm: 0.3143727481365204
# Total weight diff: 22090.330811, Max weight diff: 12563.282227
# mse and l0 loss: 371180.28125
# R_loss: 0.7977809309959412
# Average R_score: 0.20221906900405884
# gradient_norm: 0.3377186954021454
# Total weight diff: 20582.483962, Max weight diff: 11660.007812
# mse and l0 loss: 263154.5625
# R_loss: 0.7581015825271606
# Average R_score: 0.24189843237400055
# gradient_norm: 0.32791662216186523
# Total weight diff: 19121.438072, Max weight diff: 11017.258789
# mse and l0 loss: 129345.6015625
# R_loss: 0.7584342360496521
# Average R_score: 0.2415657788515091
# gradient_norm: 0.17981353402137756
# Total weight diff: 17481.848861, Max weight diff: 10140.837891
# mse and l0 loss: 143333.203125
# R_loss: 0.7813361883163452
# Average R_score: 0.21866381168365479
# gradient_norm: 0.1885337382555008
# Total weight diff: 15676.913571, Max weight diff: 9258.648438
# mse and l0 loss: 173533.078125
# R_loss: 0.8737115859985352
# Average R_score: 0.12628844380378723
# gradient_norm: 0.1973896473646164
# Total weight diff: 14134.314259, Max weight diff: 8530.877930
# mse and l0 loss: 657384.0625
# R_loss: 0.7836635708808899
# Average R_score: 0.2163364291191101
# gradient_norm: 0.683725893497467
# Total weight diff: 14726.200892, Max weight diff: 9179.203125
# mse and l0 loss: 2434476.75
# R_loss: 0.7669044733047485
# Average R_score: 0.23309554159641266
# gradient_norm: 1.8421523571014404
# Total weight diff: 28103.335587, Max weight diff: 14496.937500
# mse and l0 loss: 139797.390625
# R_loss: 0.8782893419265747
# Average R_score: 0.1217106357216835
# gradient_norm: 0.18379941582679749
# Total weight diff: 25871.530894, Max weight diff: 13217.280273
# mse and l0 loss: 350118.3125
# R_loss: 0.8742337226867676
# Average R_score: 0.12576627731323242
# gradient_norm: 0.3347664773464203
# Total weight diff: 25606.829072, Max weight diff: 13351.010742
# mse and l0 loss: 116414.3203125
# R_loss: 0.7210514545440674
# Average R_score: 0.2789485454559326
# gradient_norm: 0.174600750207901
# Total weight diff: 23290.117036, Max weight diff: 12141.615234
# mse and l0 loss: 678995.25
# R_loss: 0.7576111555099487
# Average R_score: 0.24238885939121246
# gradient_norm: 0.5494739413261414
# Total weight diff: 20348.289715, Max weight diff: 10464.986328
# mse and l0 loss: 150366.78125
# R_loss: 0.8719062209129333
# Average R_score: 0.12809376418590546
# gradient_norm: 0.2005535364151001
# Total weight diff: 18426.196412, Max weight diff: 9695.123047
# mse and l0 loss: 312461.3125
# R_loss: 0.7091531753540039
# Average R_score: 0.2908468246459961
# gradient_norm: 0.3780645430088043
# Total weight diff: 16707.548202, Max weight diff: 9253.527344
# mse and l0 loss: 94588.625
# R_loss: 0.8732226490974426
# Average R_score: 0.12677733600139618
# gradient_norm: 0.1584227830171585
# Total weight diff: 15208.540011, Max weight diff: 8484.720703
# mse and l0 loss: 1454940.5
# R_loss: 0.7522343397140503
# Average R_score: 0.2477656453847885
# gradient_norm: 1.249544382095337
# Total weight diff: 20756.619154, Max weight diff: 10806.714844
# mse and l0 loss: 379931.8125
# R_loss: 0.8852721452713013
# Average R_score: 0.11472783982753754
# gradient_norm: 0.3463658094406128
# Total weight diff: 20776.264932, Max weight diff: 10455.037109
# mse and l0 loss: 168567.78125
# R_loss: 0.8329756855964661
# Average R_score: 0.16702429950237274
# gradient_norm: 0.198881596326828
# Total weight diff: 19669.385697, Max weight diff: 10177.438477
# mse and l0 loss: 73246.9296875
# R_loss: 0.8264404535293579
# Average R_score: 0.1735595166683197
# gradient_norm: 0.14961665868759155
# Total weight diff: 17907.711213, Max weight diff: 9259.435547
# mse and l0 loss: 1016281.6875
# R_loss: 0.7846018671989441
# Average R_score: 0.2153981328010559
# gradient_norm: 0.8874231576919556
# Total weight diff: 17007.697605, Max weight diff: 9341.541016
# mse and l0 loss: 237320.5625
# R_loss: 0.7571012377738953
# Average R_score: 0.24289876222610474
# gradient_norm: 0.2712711989879608
# Total weight diff: 16569.827080, Max weight diff: 8784.236328
# mse and l0 loss: 151458.15625
# R_loss: 0.8820642232894897
# Average R_score: 0.11793574690818787
# gradient_norm: 0.19163921475410461
# Total weight diff: 15664.215274, Max weight diff: 8156.821289
# mse and l0 loss: 60350.515625
# R_loss: 0.746783971786499
# Average R_score: 0.253216028213501
# gradient_norm: 0.1305360198020935
# Total weight diff: 14471.612572, Max weight diff: 7462.850586
# mse and l0 loss: 112365.7890625
# R_loss: 0.8266192674636841
# Average R_score: 0.17338070273399353
# gradient_norm: 0.17092099785804749
# Total weight diff: 13661.990466, Max weight diff: 6857.717285
# mse and l0 loss: 85198.8984375
# R_loss: 0.8443636894226074
# Average R_score: 0.1556362807750702
# gradient_norm: 0.14320196211338043
# Total weight diff: 12416.560404, Max weight diff: 6303.104492
# mse and l0 loss: 86929.3671875
# R_loss: 0.6909587383270264
# Average R_score: 0.30904123187065125
# gradient_norm: 0.1266116201877594
# Total weight diff: 11320.611591, Max weight diff: 5762.861816
# mse and l0 loss: 174521.015625
# R_loss: 0.7980910539627075
# Average R_score: 0.20190897583961487
# gradient_norm: 0.2116260677576065
# Total weight diff: 10575.451692, Max weight diff: 5459.146484
# mse and l0 loss: 57566.51953125
# R_loss: 0.8384912014007568
# Average R_score: 0.16150876879692078
# gradient_norm: 0.12569375336170197
# Total weight diff: 9660.239816, Max weight diff: 5037.339844
# mse and l0 loss: 86402.7734375
# R_loss: 0.7695033550262451
# Average R_score: 0.2304966300725937
# gradient_norm: 0.14723137021064758
# Total weight diff: 8963.772762, Max weight diff: 4747.799805
# mse and l0 loss: 124023.8828125
# R_loss: 0.8419283628463745
# Average R_score: 0.15807166695594788
# gradient_norm: 0.1768808811903
# Total weight diff: 8482.446411, Max weight diff: 4536.471680
# mse and l0 loss: 106820.234375
# R_loss: 0.881691575050354
# Average R_score: 0.11830839514732361
# gradient_norm: 0.14741140604019165
# Total weight diff: 8124.319627, Max weight diff: 4338.550781
# mse and l0 loss: 62692.42578125
# R_loss: 0.6772558093070984
# Average R_score: 0.3227441906929016
# gradient_norm: 0.12035355716943741
# Total weight diff: 7722.295939, Max weight diff: 4095.125732
# mse and l0 loss: 44223.69140625
# R_loss: 0.6604040861129761
# Average R_score: 0.3395959436893463
# gradient_norm: 0.10745351761579514
# Total weight diff: 7243.103494, Max weight diff: 3812.957275
# mse and l0 loss: 73155.0078125
# R_loss: 0.7307455539703369
# Average R_score: 0.2692544460296631
# gradient_norm: 0.12509097158908844
# Total weight diff: 6676.129591, Max weight diff: 3606.562012
# mse and l0 loss: 66778.7890625
# R_loss: 0.7837868332862854
# Average R_score: 0.2162131518125534
# gradient_norm: 0.1273203194141388
# Total weight diff: 6175.362202, Max weight diff: 3409.362793
# mse and l0 loss: 33144.296875
# R_loss: 0.8468617796897888
# Average R_score: 0.15313820540905
# gradient_norm: 0.10237704962491989
# Total weight diff: 5724.780026, Max weight diff: 3167.657227
# mse and l0 loss: 42800.80859375
# R_loss: 0.7640105485916138
# Average R_score: 0.23598943650722504
# gradient_norm: 0.10900528728961945
# Total weight diff: 5277.198229, Max weight diff: 3002.109863
# mse and l0 loss: 60369.37109375
# R_loss: 0.8456379771232605
# Average R_score: 0.1543620377779007
# gradient_norm: 0.13970144093036652
# Total weight diff: 5083.589433, Max weight diff: 2907.228516
# mse and l0 loss: 48341.12890625
# R_loss: 0.7689459323883057
# Average R_score: 0.23105403780937195
# gradient_norm: 0.12894116342067719
# Total weight diff: 4849.384894, Max weight diff: 2803.067139
# mse and l0 loss: 45020.33203125
# R_loss: 0.6870366334915161
# Average R_score: 0.3129633367061615
# gradient_norm: 0.1093817725777626
# Total weight diff: 4599.815842, Max weight diff: 2636.545898
# mse and l0 loss: 22813.609375
# R_loss: 0.659875750541687
# Average R_score: 0.3401242196559906
# gradient_norm: 0.10656626522541046
# Total weight diff: 4350.181070, Max weight diff: 2470.809570
# mse and l0 loss: 53075.375
# R_loss: 0.8702880144119263
# Average R_score: 0.12971195578575134
# gradient_norm: 0.11474287509918213
# Total weight diff: 4324.388833, Max weight diff: 2441.321289
# mse and l0 loss: 14657.75390625
# R_loss: 0.8265237212181091
# Average R_score: 0.17347629368305206
# gradient_norm: 0.1171971783041954
# Total weight diff: 3942.081043, Max weight diff: 2256.068604
# mse and l0 loss: 22521.083984375
# R_loss: 0.6754890084266663
# Average R_score: 0.32451099157333374
# gradient_norm: 0.09593561291694641
# Total weight diff: 3717.393450, Max weight diff: 2111.485352
# mse and l0 loss: 35732.8671875
# R_loss: 0.7961673736572266
# Average R_score: 0.20383265614509583
# gradient_norm: 0.11078726500272751
# Total weight diff: 3652.471385, Max weight diff: 2039.208984
# mse and l0 loss: 15946.6171875
# R_loss: 0.6595775485038757
# Average R_score: 0.34042245149612427
# gradient_norm: 0.09831291437149048
# Total weight diff: 3390.364221, Max weight diff: 1890.289673
# mse and l0 loss: 19027.5625
# R_loss: 0.8504751920700073
# Average R_score: 0.14952482283115387
# gradient_norm: 0.11290743201971054
# Total weight diff: 3185.619474, Max weight diff: 1782.442627
# mse and l0 loss: 9040.1328125
# R_loss: 0.5849634408950806
# Average R_score: 0.41503655910491943
# gradient_norm: 0.09776323288679123
# Total weight diff: 2941.468625, Max weight diff: 1650.267090
# mse and l0 loss: 29530.806640625
# R_loss: 0.7371905446052551
# Average R_score: 0.2628094553947449
# gradient_norm: 0.23150482773780823
# Total weight diff: 3005.518344, Max weight diff: 1667.265137
# mse and l0 loss: 20979.03515625
# R_loss: 0.6583206653594971
# Average R_score: 0.34167930483818054
# gradient_norm: 0.08571768552064896
# Total weight diff: 2914.119452, Max weight diff: 1586.781494
# mse and l0 loss: 10657.2724609375
# R_loss: 0.7695659399032593
# Average R_score: 0.23043407499790192
# gradient_norm: 0.11859425902366638
# Total weight diff: 2694.969750, Max weight diff: 1478.030029
# mse and l0 loss: 31364.951171875
# R_loss: 0.6894922852516174
# Average R_score: 0.31050771474838257
# gradient_norm: 0.10175122320652008
# Total weight diff: 2789.563371, Max weight diff: 1489.721069
# mse and l0 loss: 15843.6806640625
# R_loss: 0.8595984578132629
# Average R_score: 0.14040152728557587
# gradient_norm: 0.1049325093626976
# Total weight diff: 2607.873919, Max weight diff: 1416.886475
# mse and l0 loss: 12772.0732421875
# R_loss: 0.8396682739257812
# Average R_score: 0.16033174097537994
# gradient_norm: 0.12981058657169342
# Total weight diff: 2453.176253, Max weight diff: 1342.771973
# mse and l0 loss: 11802.8359375
# R_loss: 0.6671806573867798
# Average R_score: 0.3328193724155426
# gradient_norm: 0.08902395516633987
# Total weight diff: 2305.420404, Max weight diff: 1258.973145
# mse and l0 loss: 15903.7626953125
# R_loss: 0.6422741413116455
# Average R_score: 0.3577258586883545
# gradient_norm: 0.08722800016403198
# Total weight diff: 2135.365953, Max weight diff: 1199.766113
# mse and l0 loss: 10186.37109375
# R_loss: 0.8186465501785278
# Average R_score: 0.18135342001914978
# gradient_norm: 0.10348477214574814
# Total weight diff: 1989.136946, Max weight diff: 1144.448608
# mse and l0 loss: 38645.75
# R_loss: 0.8619417548179626
# Average R_score: 0.13805823028087616
# gradient_norm: 0.12307820469141006
# Total weight diff: 2486.092466, Max weight diff: 1363.343628
# mse and l0 loss: 29559.501953125
# R_loss: 0.7192671298980713
# Average R_score: 0.2807328999042511
# gradient_norm: 0.10848858952522278
# Total weight diff: 2648.410004, Max weight diff: 1354.634399
# mse and l0 loss: 21619.841796875
# R_loss: 0.6125578880310059
# Average R_score: 0.38744214177131653
# gradient_norm: 0.08914638310670853
# Total weight diff: 2531.595872, Max weight diff: 1315.134888
# mse and l0 loss: 10420.697265625
# R_loss: 0.5816327333450317
# Average R_score: 0.41836729645729065
# gradient_norm: 0.07420755177736282
# Total weight diff: 2307.459805, Max weight diff: 1228.883057
# mse and l0 loss: 17030.36328125
# R_loss: 0.6964387893676758
# Average R_score: 0.3035612106323242
# gradient_norm: 0.08928519487380981
# Total weight diff: 2189.923602, Max weight diff: 1179.261475
# mse and l0 loss: 10844.5830078125
# R_loss: 0.7336081266403198
# Average R_score: 0.2663918435573578
# gradient_norm: 0.1134059950709343
# Total weight diff: 2055.492791, Max weight diff: 1114.501709
# mse and l0 loss: 19846.537109375
# R_loss: 0.8456390500068665
# Average R_score: 0.15436094999313354
# gradient_norm: 0.11602328717708588
# Total weight diff: 2113.704480, Max weight diff: 1122.825806
# mse and l0 loss: 36725.6875
# R_loss: 0.7693712711334229
# Average R_score: 0.23062875866889954
# gradient_norm: 0.12090617418289185
# Total weight diff: 2611.362586, Max weight diff: 1376.857422
# mse and l0 loss: 18945.080078125
# R_loss: 0.592443585395813
# Average R_score: 0.4075564444065094
# gradient_norm: 0.07643097639083862
# Total weight diff: 2677.014929, Max weight diff: 1346.221924
# mse and l0 loss: 16467.759765625
# R_loss: 0.8039401173591614
# Average R_score: 0.19605989754199982
# gradient_norm: 0.1002504825592041
# Total weight diff: 2724.334263, Max weight diff: 1374.550781
# mse and l0 loss: 9845.078125
# R_loss: 0.6842200756072998
# Average R_score: 0.3157799243927002
# gradient_norm: 0.09990984946489334
# Total weight diff: 2572.559198, Max weight diff: 1310.889160
# mse and l0 loss: 7700.1650390625
# R_loss: 0.5294439792633057
# Average R_score: 0.47055599093437195
# gradient_norm: 0.07437573373317719
# Total weight diff: 2382.324971, Max weight diff: 1213.582642
# mse and l0 loss: 13949.7216796875
# R_loss: 0.8005071878433228
# Average R_score: 0.19949279725551605
# gradient_norm: 0.08378344774246216
# Total weight diff: 2228.005108, Max weight diff: 1133.286865
# mse and l0 loss: 11277.6533203125
# R_loss: 0.7607585191726685
# Average R_score: 0.23924151062965393
# gradient_norm: 0.09716080874204636
# Total weight diff: 2094.980650, Max weight diff: 1096.190674
# mse and l0 loss: 17392.19921875
# R_loss: 0.6404193639755249
# Average R_score: 0.3595806062221527
# gradient_norm: 0.07773119956254959
# Total weight diff: 2013.109155, Max weight diff: 1088.886719
# mse and l0 loss: 9558.888671875
# R_loss: 0.5994255542755127
# Average R_score: 0.4005744159221649
# gradient_norm: 0.10361143201589584
# Total weight diff: 1870.288059, Max weight diff: 1021.216003
# mse and l0 loss: 27405.744140625
# R_loss: 0.6644108295440674
# Average R_score: 0.335589200258255
# gradient_norm: 0.10872787237167358
# Total weight diff: 2104.075126, Max weight diff: 1086.385498
# mse and l0 loss: 11608.873046875
# R_loss: 0.8075679540634155
# Average R_score: 0.19243201613426208
# gradient_norm: 0.12258100509643555
# Total weight diff: 1990.657132, Max weight diff: 1043.497681
# mse and l0 loss: 23281.203125
# R_loss: 0.599600076675415
# Average R_score: 0.4003998935222626
# gradient_norm: 0.11302006244659424
# Total weight diff: 2278.222905, Max weight diff: 1168.142090
# mse and l0 loss: 7387.88232421875
# R_loss: 0.647571325302124
# Average R_score: 0.35242870450019836
# gradient_norm: 0.09886187314987183
# Total weight diff: 2097.078188, Max weight diff: 1065.765381
# mse and l0 loss: 11977.009765625
# R_loss: 0.8513758182525635
# Average R_score: 0.14862416684627533
# gradient_norm: 0.23141717910766602
# Total weight diff: 2081.347359, Max weight diff: 1043.260620
# mse and l0 loss: 12457.5986328125
# R_loss: 0.5930508971214294
# Average R_score: 0.40694910287857056
# gradient_norm: 0.08829167485237122
# Total weight diff: 1982.362018, Max weight diff: 996.003906
# mse and l0 loss: 8292.890625
# R_loss: 0.5880734920501709
# Average R_score: 0.4119264781475067
# gradient_norm: 0.08751734346151352
# Total weight diff: 1814.445264, Max weight diff: 917.375305
# mse and l0 loss: 10429.537109375
# R_loss: 0.7689631581306458
# Average R_score: 0.23103685677051544
# gradient_norm: 0.09148114174604416
# Total weight diff: 1757.685433, Max weight diff: 888.872681
# mse and l0 loss: 31140.3828125
# R_loss: 0.6987755298614502
# Average R_score: 0.3012244999408722
# gradient_norm: 0.12485361844301224
# Total weight diff: 2033.090819, Max weight diff: 1138.211182
# mse and l0 loss: 13216.0302734375
# R_loss: 0.7023303508758545
# Average R_score: 0.2976696193218231
# gradient_norm: 0.10701295733451843
# Total weight diff: 2045.743055, Max weight diff: 1109.088379
# mse and l0 loss: 8937.2529296875
# R_loss: 0.7649203538894653
# Average R_score: 0.23507961630821228
# gradient_norm: 0.10232168436050415
# Total weight diff: 1916.761733, Max weight diff: 1048.187134
# mse and l0 loss: 8480.3583984375
# R_loss: 0.7818984985351562
# Average R_score: 0.21810153126716614
# gradient_norm: 0.10698147118091583
# Total weight diff: 1798.242400, Max weight diff: 1000.930420
# mse and l0 loss: 8386.673828125
# R_loss: 0.5477957725524902
# Average R_score: 0.45220422744750977
# gradient_norm: 0.07176461070775986
# Total weight diff: 1684.998368, Max weight diff: 941.404297
# mse and l0 loss: 7941.0341796875
# R_loss: 0.6276806592941284
# Average R_score: 0.3723193407058716
# gradient_norm: 0.07579144835472107
# Total weight diff: 1570.618691, Max weight diff: 885.332397
# mse and l0 loss: 25558.4453125
# R_loss: 0.6445782780647278
# Average R_score: 0.3554217219352722
# gradient_norm: 0.12493961304426193
# Total weight diff: 1925.937449, Max weight diff: 1041.983887
# mse and l0 loss: 14121.396484375
# R_loss: 0.846703827381134
# Average R_score: 0.15329618752002716
# gradient_norm: 0.12926533818244934
# Total weight diff: 1908.659382, Max weight diff: 1020.194275
# mse and l0 loss: 11028.447265625
# R_loss: 0.5688327550888062
# Average R_score: 0.43116724491119385
# gradient_norm: 0.06389916688203812
# Total weight diff: 1844.880297, Max weight diff: 987.417847
# mse and l0 loss: 13117.4931640625
# R_loss: 0.5709613561630249
# Average R_score: 0.4290386438369751
# gradient_norm: 0.06877725571393967
# Total weight diff: 1874.846900, Max weight diff: 988.852051
# mse and l0 loss: 7414.12353515625
# R_loss: 0.815849244594574
# Average R_score: 0.18415077030658722
# gradient_norm: 0.0982278436422348
# Total weight diff: 1758.701593, Max weight diff: 940.775574
# mse and l0 loss: 7510.53955078125
# R_loss: 0.8322374820709229
# Average R_score: 0.16776253283023834
# gradient_norm: 0.09363096207380295
# Total weight diff: 1642.750755, Max weight diff: 898.010376
# mse and l0 loss: 7376.154296875
# R_loss: 0.6183507442474365
# Average R_score: 0.38164928555488586
# gradient_norm: 0.07616282999515533
# Total weight diff: 1546.492139, Max weight diff: 846.971924
# mse and l0 loss: 19293.654296875
# R_loss: 0.5984794497489929
# Average R_score: 0.4015205502510071
# gradient_norm: 0.07772510498762131
# Total weight diff: 1674.776645, Max weight diff: 879.596436
# mse and l0 loss: 11982.388671875
# R_loss: 0.7733371257781982
# Average R_score: 0.22666285932064056
# gradient_norm: 0.08490654081106186
# Total weight diff: 1590.958188, Max weight diff: 875.872925
# mse and l0 loss: 7104.82470703125
# R_loss: 0.7049126625061035
# Average R_score: 0.2950873076915741
# gradient_norm: 0.08450271934270859
# Total weight diff: 1481.277822, Max weight diff: 829.768372
# mse and l0 loss: 10568.1806640625
# R_loss: 0.5638892650604248
# Average R_score: 0.4361107647418976
# gradient_norm: 0.07429105788469315
# Total weight diff: 1480.294409, Max weight diff: 812.535400
# mse and l0 loss: 9285.6142578125
# R_loss: 0.8300255537033081
# Average R_score: 0.1699744164943695
# gradient_norm: 0.09655164927244186
# Total weight diff: 1433.534875, Max weight diff: 800.150330
# mse and l0 loss: 6585.3212890625
# R_loss: 0.7561955451965332
# Average R_score: 0.2438044399023056
# gradient_norm: 0.12246005237102509
# Total weight diff: 1340.890157, Max weight diff: 763.380005
# mse and l0 loss: 8153.32177734375
# R_loss: 0.5913142561912537
# Average R_score: 0.40868574380874634
# gradient_norm: 0.06883043795824051
# Total weight diff: 1256.190413, Max weight diff: 727.058838
# mse and l0 loss: 6672.4521484375
# R_loss: 0.7014033794403076
# Average R_score: 0.29859665036201477
# gradient_norm: 0.10816202312707901
# Total weight diff: 1166.585319, Max weight diff: 692.313538
# mse and l0 loss: 12351.01171875
# R_loss: 0.6700814962387085
# Average R_score: 0.3299184739589691
# gradient_norm: 0.15799535810947418
# Total weight diff: 1293.643913, Max weight diff: 740.175415
# mse and l0 loss: 6602.06640625
# R_loss: 0.5464626550674438
# Average R_score: 0.45353731513023376
# gradient_norm: 0.06745871156454086
# Total weight diff: 1200.095777, Max weight diff: 692.459473
# mse and l0 loss: 8786.234375
# R_loss: 0.6680086851119995
# Average R_score: 0.3319913148880005
# gradient_norm: 0.14207087457180023
# Total weight diff: 1128.151495, Max weight diff: 656.716919
# mse and l0 loss: 7681.4208984375
# R_loss: 0.584861159324646
# Average R_score: 0.4151388704776764
# gradient_norm: 0.06446801126003265
# Total weight diff: 1051.078931, Max weight diff: 630.256592
# mse and l0 loss: 8827.197265625
# R_loss: 0.6455273628234863
# Average R_score: 0.35447263717651367
# gradient_norm: 0.0727602168917656
# Total weight diff: 1004.211803, Max weight diff: 609.391602
# mse and l0 loss: 6902.880859375
# R_loss: 0.7322666645050049
# Average R_score: 0.2677333652973175
# gradient_norm: 0.09557565301656723
# Total weight diff: 944.358733, Max weight diff: 591.860474
# mse and l0 loss: 6150.82568359375
# R_loss: 0.5212111473083496
# Average R_score: 0.4787888824939728
# gradient_norm: 0.06766301393508911
# Total weight diff: 881.420784, Max weight diff: 554.969910
# mse and l0 loss: 6858.5185546875
# R_loss: 0.5248512029647827
# Average R_score: 0.4751488268375397
# gradient_norm: 0.07064341753721237
# Total weight diff: 853.751084, Max weight diff: 537.012878
# mse and l0 loss: 7727.24755859375
# R_loss: 0.744513750076294
# Average R_score: 0.25548622012138367
# gradient_norm: 0.10142823308706284
# Total weight diff: 884.633564, Max weight diff: 553.622620
# mse and l0 loss: 29256.294921875
# R_loss: 0.6621832251548767
# Average R_score: 0.3378167748451233
# gradient_norm: 0.2130092829465866
# Total weight diff: 2067.988636, Max weight diff: 1073.044678
# mse and l0 loss: 8289.8798828125
# R_loss: 0.6284809112548828
# Average R_score: 0.3715190887451172
# gradient_norm: 0.07394294440746307
# Total weight diff: 1928.585572, Max weight diff: 990.919922
# mse and l0 loss: 6312.6650390625
# R_loss: 0.5038334131240845
# Average R_score: 0.49616655707359314
# gradient_norm: 0.07229749113321304
# Total weight diff: 1773.064461, Max weight diff: 904.259155
# mse and l0 loss: 8097.5234375
# R_loss: 0.5510400533676147
# Average R_score: 0.44895994663238525
# gradient_norm: 0.06699255108833313
# Total weight diff: 1678.551140, Max weight diff: 849.711548
# mse and l0 loss: 8371.984375
# R_loss: 0.5210643410682678
# Average R_score: 0.4789356589317322
# gradient_norm: 0.06326811760663986
# Total weight diff: 1613.846277, Max weight diff: 818.543823
# mse and l0 loss: 7154.919921875
# R_loss: 0.6928900480270386
# Average R_score: 0.3071099519729614
# gradient_norm: 0.08775755763053894
# Total weight diff: 1496.335024, Max weight diff: 755.085327
# mse and l0 loss: 9504.322265625
# R_loss: 0.7364240884780884
# Average R_score: 0.2635759115219116
# gradient_norm: 0.0784381702542305
# Total weight diff: 1438.384481, Max weight diff: 746.440063
# mse and l0 loss: 6309.7275390625
# R_loss: 0.5074394941329956
# Average R_score: 0.4925605058670044
# gradient_norm: 0.07277286052703857
# Total weight diff: 1342.996191, Max weight diff: 697.887817
# mse and l0 loss: 6523.896484375
# R_loss: 0.7427395582199097
# Average R_score: 0.25726041197776794
# gradient_norm: 0.09223277866840363
# Total weight diff: 1236.277982, Max weight diff: 663.793457
# mse and l0 loss: 12230.05078125
# R_loss: 0.7373120784759521
# Average R_score: 0.26268792152404785
# gradient_norm: 0.09229305386543274
# Total weight diff: 1361.075074, Max weight diff: 710.458191
# mse and l0 loss: 9263.5615234375
# R_loss: 0.5988012552261353
# Average R_score: 0.40119877457618713
# gradient_norm: 0.07683026045560837
# Total weight diff: 1320.914004, Max weight diff: 685.283447
# mse and l0 loss: 7092.23486328125
# R_loss: 0.7328903079032898
# Average R_score: 0.2671096920967102
# gradient_norm: 0.07952713966369629
# Total weight diff: 1237.628702, Max weight diff: 654.097534
# mse and l0 loss: 6871.86083984375
# R_loss: 0.756982684135437
# Average R_score: 0.2430172860622406
# gradient_norm: 0.09651804715394974
# Total weight diff: 1160.560439, Max weight diff: 633.194275
# mse and l0 loss: 12317.548828125
# R_loss: 0.5600557327270508
# Average R_score: 0.4399442970752716
# gradient_norm: 0.08554484695196152
# Total weight diff: 1183.201980, Max weight diff: 641.782227
# mse and l0 loss: 7727.474609375
# R_loss: 0.5914673805236816
# Average R_score: 0.40853261947631836
# gradient_norm: 0.08162705600261688
# Total weight diff: 1104.566592, Max weight diff: 614.953613
# mse and l0 loss: 8372.2724609375
# R_loss: 0.5981078147888184
# Average R_score: 0.40189215540885925
# gradient_norm: 0.06610758602619171
# Total weight diff: 1088.545077, Max weight diff: 597.836792
# mse and l0 loss: 5902.837890625
# R_loss: 0.7923731207847595
# Average R_score: 0.20762686431407928
# gradient_norm: 0.10116413980722427
# Total weight diff: 1024.507122, Max weight diff: 576.177979
# mse and l0 loss: 7413.6201171875
# R_loss: 0.6455701589584351
# Average R_score: 0.35442987084388733
# gradient_norm: 0.07972978800535202
# Total weight diff: 994.898841, Max weight diff: 557.458130
# mse and l0 loss: 7750.88818359375
# R_loss: 0.493843138217926
# Average R_score: 0.506156861782074
# gradient_norm: 0.06207071617245674
# Total weight diff: 941.065369, Max weight diff: 532.140991
# mse and l0 loss: 13119.03125
# R_loss: 0.5598214864730835
# Average R_score: 0.4401784837245941
# gradient_norm: 0.07224097102880478
# Total weight diff: 1138.436829, Max weight diff: 600.010803
# mse and l0 loss: 6957.279296875
# R_loss: 0.5052056312561035
# Average R_score: 0.49479439854621887
# gradient_norm: 0.07242342829704285
# Total weight diff: 1069.558732, Max weight diff: 569.727600
# mse and l0 loss: 6937.82568359375
# R_loss: 0.5482205152511597
# Average R_score: 0.45177945494651794
# gradient_norm: 0.07248005270957947
# Total weight diff: 1012.443798, Max weight diff: 548.388184
# mse and l0 loss: 12541.0224609375
# R_loss: 0.5609954595565796
# Average R_score: 0.439004510641098
# gradient_norm: 0.06229284778237343
# Total weight diff: 1244.637151, Max weight diff: 628.301147
# mse and l0 loss: 6923.0869140625
# R_loss: 0.6472998857498169
# Average R_score: 0.3527000844478607
# gradient_norm: 0.07548869401216507
# Total weight diff: 1179.959703, Max weight diff: 591.317627
# mse and l0 loss: 7359.6806640625
# R_loss: 0.7743823528289795
# Average R_score: 0.2256176620721817
# gradient_norm: 0.078068807721138
# Total weight diff: 1129.493248, Max weight diff: 585.053528
# mse and l0 loss: 6781.2451171875
# R_loss: 0.5503326654434204
# Average R_score: 0.4496673345565796
# gradient_norm: 0.05842014029622078
# Total weight diff: 1056.266417, Max weight diff: 557.985474
# mse and l0 loss: 12507.21484375
# R_loss: 0.7434074878692627
# Average R_score: 0.2565924823284149
# gradient_norm: 0.077904611825943
# Total weight diff: 1150.844936, Max weight diff: 594.066833
# mse and l0 loss: 11778.3896484375
# R_loss: 0.5571447610855103
# Average R_score: 0.44285523891448975
# gradient_norm: 0.0584600605070591
# Total weight diff: 1240.193396, Max weight diff: 623.523438
# mse and l0 loss: 9381.9697265625
# R_loss: 0.8485956192016602
# Average R_score: 0.15140435099601746
# gradient_norm: 0.09534130245447159
# Total weight diff: 1301.239302, Max weight diff: 658.285645
# mse and l0 loss: 7653.78955078125
# R_loss: 0.6330143213272095
# Average R_score: 0.3669856786727905
# gradient_norm: 0.07041200250387192
# Total weight diff: 1230.434501, Max weight diff: 639.354675
# mse and l0 loss: 5898.62841796875
# R_loss: 0.7400786876678467
# Average R_score: 0.2599213123321533
# gradient_norm: 0.08453752845525742
# Total weight diff: 1155.757575, Max weight diff: 618.255371
# mse and l0 loss: 6740.728515625
# R_loss: 0.7493256330490112
# Average R_score: 0.25067439675331116
# gradient_norm: 0.10312192887067795
# Total weight diff: 1085.360451, Max weight diff: 596.497192
# mse and l0 loss: 7524.56005859375
# R_loss: 0.6280913352966309
# Average R_score: 0.37190866470336914
# gradient_norm: 0.07480217516422272
# Total weight diff: 1052.029162, Max weight diff: 587.873169
# mse and l0 loss: 6473.3115234375
# R_loss: 0.6761317253112793
# Average R_score: 0.3238682448863983
# gradient_norm: 0.07092108577489853
# Total weight diff: 996.952441, Max weight diff: 561.031616
# mse and l0 loss: 6582.31787109375
# R_loss: 0.6797946691513062
# Average R_score: 0.32020530104637146
# gradient_norm: 0.07899738848209381
# Total weight diff: 945.569816, Max weight diff: 552.185120
# mse and l0 loss: 6174.525390625
# R_loss: 0.534379780292511
# Average R_score: 0.465620219707489
# gradient_norm: 0.06669102609157562
# Total weight diff: 892.219851, Max weight diff: 530.719910
# mse and l0 loss: 6711.791015625
# R_loss: 0.49830520153045654
# Average R_score: 0.5016947984695435
# gradient_norm: 0.05970126390457153
# Total weight diff: 845.296380, Max weight diff: 503.242249
# mse and l0 loss: 6422.4970703125
# R_loss: 0.8060052394866943
# Average R_score: 0.19399473071098328
# gradient_norm: 0.09806396067142487
# Total weight diff: 835.950947, Max weight diff: 502.317139
# mse and l0 loss: 11449.59375
# R_loss: 0.5430090427398682
# Average R_score: 0.45699095726013184
# gradient_norm: 0.06064989045262337
# Total weight diff: 1019.748636, Max weight diff: 573.626282
# mse and l0 loss: 5767.732421875
# R_loss: 0.46610182523727417
# Average R_score: 0.5338981747627258
# gradient_norm: 0.06505463272333145
# Total weight diff: 953.867579, Max weight diff: 534.793945
# mse and l0 loss: 12861.1748046875
# R_loss: 0.5883394479751587
# Average R_score: 0.4116605520248413
# gradient_norm: 0.09689070284366608
# Total weight diff: 1184.837518, Max weight diff: 673.894714
# mse and l0 loss: 6027.29541015625
# R_loss: 0.596697211265564
# Average R_score: 0.40330275893211365
# gradient_norm: 0.07715752720832825
# Total weight diff: 1100.483454, Max weight diff: 629.019104
# mse and l0 loss: 6225.875
# R_loss: 0.8029571771621704
# Average R_score: 0.1970428079366684
# gradient_norm: 0.08706486970186234
# Total weight diff: 1050.498001, Max weight diff: 620.933533
# mse and l0 loss: 5801.01123046875
# R_loss: 0.6771966218948364
# Average R_score: 0.3228033781051636
# gradient_norm: 0.08435752987861633
# Total weight diff: 1001.330088, Max weight diff: 590.666565
# mse and l0 loss: 8167.73681640625
# R_loss: 0.7640348672866821
# Average R_score: 0.23596513271331787
# gradient_norm: 0.10374923050403595
# Total weight diff: 964.281392, Max weight diff: 585.924011
# mse and l0 loss: 7337.44970703125
# R_loss: 0.7965501546859741
# Average R_score: 0.2034498155117035
# gradient_norm: 0.09830302000045776
# Total weight diff: 936.750261, Max weight diff: 574.302490
# mse and l0 loss: 38370.12890625
# R_loss: 0.7074685096740723
# Average R_score: 0.29253146052360535
# gradient_norm: 0.11590532958507538
# Total weight diff: 2489.509082, Max weight diff: 1332.769287
# mse and l0 loss: 8857.615234375
# R_loss: 0.5595899224281311
# Average R_score: 0.4404100775718689
# gradient_norm: 0.06152169778943062
# Total weight diff: 2255.956628, Max weight diff: 1180.174072
# mse and l0 loss: 8906.076171875
# R_loss: 0.5022913217544556
# Average R_score: 0.49770867824554443
# gradient_norm: 0.060189954936504364
# Total weight diff: 2024.669215, Max weight diff: 1016.946533
# mse and l0 loss: 6062.31298828125
# R_loss: 0.7357768416404724
# Average R_score: 0.2642231583595276
# gradient_norm: 0.09540969133377075
# Total weight diff: 1854.004236, Max weight diff: 943.801636
# mse and l0 loss: 8908.4814453125
# R_loss: 0.7772655487060547
# Average R_score: 0.2227344661951065
# gradient_norm: 0.1016840860247612
# Total weight diff: 1709.586885, Max weight diff: 897.511963
# mse and l0 loss: 6835.490234375
# R_loss: 0.5225585699081421
# Average R_score: 0.4774414300918579
# gradient_norm: 0.05245283991098404
# Total weight diff: 1565.071716, Max weight diff: 835.651917
# mse and l0 loss: 6926.85498046875
# R_loss: 0.6769171953201294
# Average R_score: 0.3230828046798706
# gradient_norm: 0.07398773729801178
# Total weight diff: 1467.325778, Max weight diff: 790.090088
# mse and l0 loss: 5793.54150390625
# R_loss: 0.5067602396011353
# Average R_score: 0.49323979020118713
# gradient_norm: 0.06366879492998123
# Total weight diff: 1353.884441, Max weight diff: 735.742371
# mse and l0 loss: 6418.134765625
# R_loss: 0.5626492500305176
# Average R_score: 0.4373507499694824
# gradient_norm: 0.059478554874658585
# Total weight diff: 1250.946926, Max weight diff: 686.342224
# mse and l0 loss: 11495.5185546875
# R_loss: 0.5910459160804749
# Average R_score: 0.40895408391952515
# gradient_norm: 0.05890202149748802
# Total weight diff: 1341.357081, Max weight diff: 712.195251
# mse and l0 loss: 7814.98876953125
# R_loss: 0.767160952091217
# Average R_score: 0.23283903300762177
# gradient_norm: 0.07410698384046555
# Total weight diff: 1274.841651, Max weight diff: 689.864502
# mse and l0 loss: 14428.87109375
# R_loss: 0.7295361757278442
# Average R_score: 0.27046382427215576
# gradient_norm: 0.20641599595546722
# Total weight diff: 1397.030978, Max weight diff: 760.262146
# mse and l0 loss: 9929.2275390625
# R_loss: 0.755647599697113
# Average R_score: 0.24435238540172577
# gradient_norm: 0.0815485492348671
# Total weight diff: 1482.852128, Max weight diff: 755.273315
# mse and l0 loss: 6848.3828125
# R_loss: 0.7027590274810791
# Average R_score: 0.2972410023212433
# gradient_norm: 0.09456600993871689
# Total weight diff: 1408.205673, Max weight diff: 710.087219
# mse and l0 loss: 6407.07080078125
# R_loss: 0.8420564532279968
# Average R_score: 0.15794353187084198
# gradient_norm: 0.09339022636413574
# Total weight diff: 1319.056931, Max weight diff: 677.140381
# mse and l0 loss: 9891.576171875
# R_loss: 0.8414185047149658
# Average R_score: 0.15858149528503418
# gradient_norm: 0.08488842099905014
# Total weight diff: 1473.916247, Max weight diff: 776.443176
# mse and l0 loss: 7504.82568359375
# R_loss: 0.7845451831817627
# Average R_score: 0.2154548019170761
# gradient_norm: 0.08544938266277313
# Total weight diff: 1352.446364, Max weight diff: 676.314026
# mse and l0 loss: 6626.81689453125
# R_loss: 0.7347573041915894
# Average R_score: 0.26524266600608826
# gradient_norm: 0.0700075551867485
# Total weight diff: 1263.379583, Max weight diff: 639.076172
# mse and l0 loss: 9687.029296875
# R_loss: 0.7324814796447754
# Average R_score: 0.2675185203552246
# gradient_norm: 0.08542400598526001
# Total weight diff: 1319.244961, Max weight diff: 675.807983
# mse and l0 loss: 7161.76904296875
# R_loss: 0.5043585300445557
# Average R_score: 0.49564146995544434
# gradient_norm: 0.07067792117595673
# Total weight diff: 1252.478383, Max weight diff: 651.824097
# mse and l0 loss: 7086.70166015625
# R_loss: 0.5056917667388916
# Average R_score: 0.4943082630634308
# gradient_norm: 0.052923090755939484
# Total weight diff: 1187.391684, Max weight diff: 617.308289
# mse and l0 loss: 8242.8017578125
# R_loss: 0.6718755960464478
# Average R_score: 0.32812443375587463
# gradient_norm: 0.07573416829109192
# Total weight diff: 1170.447737, Max weight diff: 604.897644
# mse and l0 loss: 9472.9970703125
# R_loss: 0.7267988920211792
# Average R_score: 0.2732010781764984
# gradient_norm: 0.06943177431821823
# Total weight diff: 1290.165983, Max weight diff: 697.048462
# mse and l0 loss: 6098.568359375
# R_loss: 0.6433906555175781
# Average R_score: 0.3566093146800995
# gradient_norm: 0.0655457079410553
# Total weight diff: 1228.771904, Max weight diff: 666.825745
# mse and l0 loss: 6208.728515625
# R_loss: 0.6204699277877808
# Average R_score: 0.37953004240989685
# gradient_norm: 0.06865128129720688
# Total weight diff: 1145.098246, Max weight diff: 609.931702
# mse and l0 loss: 5885.3759765625
# R_loss: 0.7230774760246277
# Average R_score: 0.2769225239753723
# gradient_norm: 0.09756927192211151
# Total weight diff: 1057.678235, Max weight diff: 549.431946
# mse and l0 loss: 7270.2138671875
# R_loss: 0.6344105005264282
# Average R_score: 0.36558952927589417
# gradient_norm: 0.0594109483063221
# Total weight diff: 984.540240, Max weight diff: 502.065918
# mse and l0 loss: 5703.60498046875
# R_loss: 0.710753858089447
# Average R_score: 0.289246141910553
# gradient_norm: 0.09381350874900818
# Total weight diff: 920.158032, Max weight diff: 484.598938
# mse and l0 loss: 5608.87158203125
# R_loss: 0.510956883430481
# Average R_score: 0.48904314637184143
# gradient_norm: 0.05227944999933243
# Total weight diff: 850.678352, Max weight diff: 458.295227
# mse and l0 loss: 6170.9658203125
# R_loss: 0.7557030320167542
# Average R_score: 0.24429698288440704
# gradient_norm: 0.078532375395298
# Total weight diff: 793.568474, Max weight diff: 451.411072
# mse and l0 loss: 6803.2939453125
# R_loss: 0.6532444953918457
# Average R_score: 0.3467555344104767
# gradient_norm: 0.07072780281305313
# Total weight diff: 766.198209, Max weight diff: 444.791565
# mse and l0 loss: 6390.92724609375
# R_loss: 0.5825984477996826
# Average R_score: 0.4174015522003174
# gradient_norm: 0.05690982937812805
# Total weight diff: 742.468587, Max weight diff: 425.044067
# mse and l0 loss: 6304.619140625
# R_loss: 0.7175222635269165
# Average R_score: 0.2824777662754059
# gradient_norm: 0.09071903675794601
# Total weight diff: 731.815780, Max weight diff: 416.776093
# mse and l0 loss: 5765.623046875
# R_loss: 0.8042547106742859
# Average R_score: 0.1957452893257141
# gradient_norm: 0.09785480052232742
# Total weight diff: 704.792064, Max weight diff: 406.895081
# mse and l0 loss: 5660.80712890625
# R_loss: 0.5062733888626099
# Average R_score: 0.49372661113739014
# gradient_norm: 0.05662248283624649
# Total weight diff: 667.726308, Max weight diff: 385.531433
# mse and l0 loss: 8910.1591796875
# R_loss: 0.5763412117958069
# Average R_score: 0.4236587882041931
# gradient_norm: 0.07371492683887482
# Total weight diff: 821.824359, Max weight diff: 432.832520
# mse and l0 loss: 5989.87890625
# R_loss: 0.5821335315704346
# Average R_score: 0.4178664982318878
# gradient_norm: 0.06164724752306938
# Total weight diff: 784.328354, Max weight diff: 415.118164
# mse and l0 loss: 6971.8740234375
# R_loss: 0.7041891813278198
# Average R_score: 0.2958108186721802
# gradient_norm: 0.09743887186050415
# Total weight diff: 808.867464, Max weight diff: 412.722107
# mse and l0 loss: 6308.8251953125
# R_loss: 0.8025240302085876
# Average R_score: 0.19747596979141235
# gradient_norm: 0.09277255088090897
# Total weight diff: 827.782167, Max weight diff: 419.843262
# mse and l0 loss: 6369.5576171875
# R_loss: 0.7343702912330627
# Average R_score: 0.26562970876693726
# gradient_norm: 0.0868411511182785
# Total weight diff: 846.953296, Max weight diff: 423.677124
# mse and l0 loss: 5751.5556640625
# R_loss: 0.5994377136230469
# ...
# Average R_score: 0.2767215371131897
# gradient_norm: 0.04039863869547844
# Total weight diff: 748.605046, Max weight diff: 398.388489
# mse and l0 loss: 2871.542236328125
# R_loss: 0.6811099052429199
# Average R_score: 0.3188900649547577
# gradient_norm: 0.04845457896590233
# Total weight diff: 712.067362, Max weight diff: 372.576782
# mse and l0 loss: 2905.6318359375
# R_loss: 0.5027165412902832
# Average R_score: 0.4972834587097168
# gradient_norm: 0.03815595805644989
# Total weight diff: 667.163106, Max weight diff: 343.055237
# mse and l0 loss: 3227.22705078125
# R_loss: 0.5504682660102844
# Average R_score: 0.4495317339897156
# gradient_norm: 0.03141893818974495
# Total weight diff: 639.028492, Max weight diff: 326.665405
# mse and l0 loss: 3061.15576171875
# R_loss: 0.5931109189987183
# Average R_score: 0.4068891108036041
# gradient_norm: 0.04343481734395027
# Total weight diff: 643.306842, Max weight diff: 327.906494
# mse and l0 loss: 2745.141845703125
# R_loss: 0.5952896475791931
# Average R_score: 0.4047103524208069
# gradient_norm: 0.0461701974272728
# Total weight diff: 611.768928, Max weight diff: 309.370239
# mse and l0 loss: 3079.998291015625
# R_loss: 0.6885111331939697
# Average R_score: 0.31148889660835266
# gradient_norm: 0.03996410593390465
# Total weight diff: 598.219524, Max weight diff: 301.180939
# mse and l0 loss: 2664.4951171875
# R_loss: 0.7128365635871887
# Average R_score: 0.2871634364128113
# gradient_norm: 0.041821423918008804
# Total weight diff: 604.210349, Max weight diff: 305.170502
# mse and l0 loss: 2902.08935546875
# R_loss: 0.5660175681114197
# Average R_score: 0.4339824318885803
# gradient_norm: 0.03652268275618553
# Total weight diff: 585.767297, Max weight diff: 295.358704
# mse and l0 loss: 3302.785400390625
# R_loss: 0.6204355359077454
# Average R_score: 0.37956446409225464
# gradient_norm: 0.05410951375961304
# Total weight diff: 646.758512, Max weight diff: 338.825623
# mse and l0 loss: 4463.90673828125
# R_loss: 0.6319736242294312
# Average R_score: 0.36802634596824646
# gradient_norm: 0.042284928262233734
# Total weight diff: 736.327498, Max weight diff: 384.490509
# mse and l0 loss: 2728.3505859375
# R_loss: 0.6418861746788025
# Average R_score: 0.3581138253211975
# gradient_norm: 0.04392820596694946
# Total weight diff: 704.694584, Max weight diff: 358.046783
# mse and l0 loss: 3015.36083984375
# R_loss: 0.7630634307861328
# Average R_score: 0.2369365692138672
# gradient_norm: 0.05201565474271774
# Total weight diff: 665.561912, Max weight diff: 333.404541
# mse and l0 loss: 2943.53076171875
# R_loss: 0.43154245615005493
# Average R_score: 0.5684575438499451
# gradient_norm: 0.02542256750166416
# Total weight diff: 663.852679, Max weight diff: 332.330841
# mse and l0 loss: 3890.869140625
# R_loss: 0.6137403249740601
# Average R_score: 0.38625967502593994
# gradient_norm: 0.03662698715925217
# Total weight diff: 944.446356, Max weight diff: 566.894775
# mse and l0 loss: 3133.839111328125
# R_loss: 0.47272372245788574
# Average R_score: 0.5272762775421143
# gradient_norm: 0.03298648074269295
# Total weight diff: 912.165958, Max weight diff: 536.462585
# mse and l0 loss: 3041.054931640625
# R_loss: 0.7430237531661987
# Average R_score: 0.25697627663612366
# gradient_norm: 0.047944553196430206
# Total weight diff: 836.736554, Max weight diff: 473.087280
# mse and l0 loss: 3075.633544921875
# R_loss: 0.6441342234611511
# Average R_score: 0.3558657765388489
# gradient_norm: 0.046272631734609604
# Total weight diff: 785.256800, Max weight diff: 438.497467
# mse and l0 loss: 3133.852783203125
# R_loss: 0.43274688720703125
# Average R_score: 0.5672531127929688
# gradient_norm: 0.03250784054398537
# Total weight diff: 731.518585, Max weight diff: 379.308014
# mse and l0 loss: 2873.83056640625
# R_loss: 0.5165209174156189
# Average R_score: 0.4834790825843811
# gradient_norm: 0.03237034007906914
# Total weight diff: 697.034274, Max weight diff: 357.704346
# mse and l0 loss: 3017.823486328125
# R_loss: 0.48708540201187134
# Average R_score: 0.5129145979881287
# gradient_norm: 0.028199169784784317
# Total weight diff: 665.332666, Max weight diff: 341.782043
# mse and l0 loss: 3395.49169921875
# R_loss: 0.6439163684844971
# Average R_score: 0.3560836613178253
# gradient_norm: 0.03723116219043732
# Total weight diff: 689.533995, Max weight diff: 364.497803
# mse and l0 loss: 2885.83447265625
# R_loss: 0.4771384596824646
# Average R_score: 0.5228615403175354
# gradient_norm: 0.028302662074565887
# Total weight diff: 647.762966, Max weight diff: 339.865295
# mse and l0 loss: 4101.751953125
# R_loss: 0.7260003089904785
# Average R_score: 0.2739996910095215
# gradient_norm: 0.05084904283285141
# Total weight diff: 737.249323, Max weight diff: 388.288269
# mse and l0 loss: 2931.4091796875
# R_loss: 0.6989724040031433
# Average R_score: 0.3010275959968567
# gradient_norm: 0.04233410209417343
# Total weight diff: 687.717564, Max weight diff: 355.049133
# mse and l0 loss: 3982.478515625
# R_loss: 0.6047909259796143
# Average R_score: 0.39520910382270813
# gradient_norm: 0.03862553834915161
# Total weight diff: 733.733774, Max weight diff: 380.319122
# mse and l0 loss: 3555.022216796875
# R_loss: 0.5973250865936279
# Average R_score: 0.40267494320869446
# gradient_norm: 0.042880166321992874
# Total weight diff: 733.201469, Max weight diff: 382.136719
# mse and l0 loss: 3074.78173828125
# R_loss: 0.5731813311576843
# Average R_score: 0.4268186688423157
# gradient_norm: 0.036536019295454025
# Total weight diff: 682.500719, Max weight diff: 352.103821
# mse and l0 loss: 5384.2333984375
# R_loss: 0.4748496413230896
# Average R_score: 0.5251503586769104
# gradient_norm: 0.030205074697732925
# Total weight diff: 1332.044509, Max weight diff: 876.911682
# mse and l0 loss: 3289.119384765625
# R_loss: 0.43660855293273926
# Average R_score: 0.5633914470672607
# gradient_norm: 0.032289549708366394
# Total weight diff: 1202.805516, Max weight diff: 777.011963
# mse and l0 loss: 3952.238037109375
# R_loss: 0.650446891784668
# Average R_score: 0.3495531380176544
# gradient_norm: 0.03495289012789726
# Total weight diff: 1055.106848, Max weight diff: 644.954712
# mse and l0 loss: 5293.7734375
# R_loss: 0.5755285024642944
# Average R_score: 0.42447149753570557
# gradient_norm: 0.03595442324876785
# Total weight diff: 1048.089627, Max weight diff: 628.996338
# mse and l0 loss: 5595.6904296875
# R_loss: 0.7370783090591431
# Average R_score: 0.2629217207431793
# gradient_norm: 0.03880676254630089
# Total weight diff: 1031.828275, Max weight diff: 590.070679
# mse and l0 loss: 3262.24951171875
# R_loss: 0.46000754833221436
# Average R_score: 0.5399924516677856
# gradient_norm: 0.02575650066137314
# Total weight diff: 1013.753300, Max weight diff: 592.638428
# mse and l0 loss: 3561.31494140625
# R_loss: 0.5087649822235107
# Average R_score: 0.49123498797416687
# gradient_norm: 0.028011849150061607
# Total weight diff: 1040.929520, Max weight diff: 618.054932
# mse and l0 loss: 3506.75390625
# R_loss: 0.4558148980140686
# Average R_score: 0.5441851019859314
# gradient_norm: 0.0258745439350605
# Total weight diff: 1020.519092, Max weight diff: 598.884521
# mse and l0 loss: 4009.65576171875
# R_loss: 0.5858144164085388
# Average R_score: 0.4141855835914612
# gradient_norm: 0.036483194679021835
# Total weight diff: 948.163980, Max weight diff: 551.572815
# mse and l0 loss: 4386.583984375
# R_loss: 0.604140043258667
# Average R_score: 0.395859956741333
# gradient_norm: 0.03526698797941208
# Total weight diff: 958.741357, Max weight diff: 558.052490
# mse and l0 loss: 2851.6064453125
# R_loss: 0.5003880262374878
# Average R_score: 0.4996119439601898
# gradient_norm: 0.028675435110926628
# Total weight diff: 892.985565, Max weight diff: 516.621582
# mse and l0 loss: 3500.923583984375
# R_loss: 0.6887416839599609
# Average R_score: 0.31125834584236145
# gradient_norm: 0.0455622598528862
# Total weight diff: 883.641080, Max weight diff: 510.714050
# mse and l0 loss: 3143.95703125
# R_loss: 0.5243521928787231
# Average R_score: 0.47564777731895447
# gradient_norm: 0.03386468440294266
# Total weight diff: 855.432281, Max weight diff: 499.677490
# mse and l0 loss: 2911.84423828125
# R_loss: 0.5225663185119629
# Average R_score: 0.4774337112903595
# gradient_norm: 0.03243444114923477
# Total weight diff: 808.654564, Max weight diff: 468.644836
# mse and l0 loss: 4363.31884765625
# R_loss: 0.7820014357566833
# Average R_score: 0.21799854934215546
# gradient_norm: 0.05639173462986946
# Total weight diff: 833.584840, Max weight diff: 475.003906
# mse and l0 loss: 3230.892578125
# R_loss: 0.6679909825325012
# Average R_score: 0.3320090174674988
# gradient_norm: 0.044500935822725296
# Total weight diff: 769.720732, Max weight diff: 418.232697
# mse and l0 loss: 2907.844482421875
# R_loss: 0.6603957414627075
# Average R_score: 0.3396042287349701
# gradient_norm: 0.05789737403392792
# Total weight diff: 725.226946, Max weight diff: 388.359680
# mse and l0 loss: 2830.1123046875
# R_loss: 0.6334103345870972
# Average R_score: 0.36658966541290283
# gradient_norm: 0.04692068323493004
# Total weight diff: 672.201578, Max weight diff: 350.747620
# mse and l0 loss: 4234.755859375
# R_loss: 0.47030383348464966
# Average R_score: 0.5296961665153503
# gradient_norm: 0.033700115978717804
# Total weight diff: 749.981562, Max weight diff: 393.970459
# mse and l0 loss: 4011.600830078125
# R_loss: 0.7065303325653076
# Average R_score: 0.2934696674346924
# gradient_norm: 0.04649052023887634
# Total weight diff: 969.837284, Max weight diff: 562.268982
# mse and l0 loss: 3043.311279296875
# R_loss: 0.708136796951294
# Average R_score: 0.29186317324638367
# gradient_norm: 0.048831332474946976
# Total weight diff: 928.687452, Max weight diff: 529.067261
# mse and l0 loss: 2902.752685546875
# R_loss: 0.45349442958831787
# Average R_score: 0.5465055704116821
# gradient_norm: 0.026025690138339996
# Total weight diff: 869.168894, Max weight diff: 492.794037
# mse and l0 loss: 2650.197021484375
# R_loss: 0.5618793964385986
# Average R_score: 0.438120573759079
# gradient_norm: 0.036720629781484604
# Total weight diff: 819.333614, Max weight diff: 461.446228
# mse and l0 loss: 2971.754150390625
# R_loss: 0.7894082069396973
# Average R_score: 0.21059179306030273
# gradient_norm: 0.05102979764342308
# Total weight diff: 775.807781, Max weight diff: 426.259399
# mse and l0 loss: 2816.656982421875
# R_loss: 0.6277649402618408
# Average R_score: 0.3722350597381592
# gradient_norm: 0.041475679725408554
# Total weight diff: 724.245232, Max weight diff: 391.331207
# mse and l0 loss: 2899.69482421875
# R_loss: 0.6280645728111267
# Average R_score: 0.3719354271888733
# gradient_norm: 0.03769972175359726
# Total weight diff: 680.388477, Max weight diff: 363.261444
# mse and l0 loss: 2901.79052734375
# R_loss: 0.6963660717010498
# Average R_score: 0.3036339581012726
# gradient_norm: 0.040741387754678726
# Total weight diff: 664.306074, Max weight diff: 348.270233
# mse and l0 loss: 2971.294189453125
# R_loss: 0.4888077974319458
# Average R_score: 0.5111922025680542
# gradient_norm: 0.02812677063047886
# Total weight diff: 651.817847, Max weight diff: 343.186249
# mse and l0 loss: 4221.8876953125
# R_loss: 0.6806361675262451
# Average R_score: 0.31936386227607727
# gradient_norm: 0.04642600938677788
# Total weight diff: 741.106069, Max weight diff: 396.142700
# mse and l0 loss: 2737.2392578125
# R_loss: 0.7605059146881104
# Average R_score: 0.23949408531188965
# gradient_norm: 0.04719161614775658
# Total weight diff: 702.634983, Max weight diff: 368.495667
# mse and l0 loss: 2589.665771484375
# R_loss: 0.5313899517059326
# Average R_score: 0.46861007809638977
# gradient_norm: 0.03271118924021721
# Total weight diff: 659.091724, Max weight diff: 342.707855
# mse and l0 loss: 3093.518798828125
# R_loss: 0.6470226049423218
# Average R_score: 0.3529774248600006
# gradient_norm: 0.05254627764225006
# Total weight diff: 636.420566, Max weight diff: 327.933441
# mse and l0 loss: 2757.905029296875
# R_loss: 0.5028879642486572
# Average R_score: 0.49711206555366516
# gradient_norm: 0.029859032481908798
# Total weight diff: 600.049883, Max weight diff: 302.228455
# mse and l0 loss: 3283.01806640625
# R_loss: 0.6599551439285278
# Average R_score: 0.3400448262691498
# gradient_norm: 0.03623392805457115
# Total weight diff: 690.886591, Max weight diff: 367.661499
# mse and l0 loss: 2765.681396484375
# R_loss: 0.4832092523574829
# Average R_score: 0.5167907476425171
# gradient_norm: 0.02821432054042816
# Total weight diff: 673.849878, Max weight diff: 363.615448
# mse and l0 loss: 3349.410400390625
# R_loss: 0.7272398471832275
# Average R_score: 0.27276018261909485
# gradient_norm: 0.05416390299797058
# Total weight diff: 704.444265, Max weight diff: 384.984558
# mse and l0 loss: 2985.527587890625
# R_loss: 0.5473264455795288
# Average R_score: 0.4526735544204712
# gradient_norm: 0.040999386459589005
# Total weight diff: 735.771966, Max weight diff: 398.964813
# mse and l0 loss: 2979.552978515625
# R_loss: 0.6114284992218018
# Average R_score: 0.38857153058052063
# gradient_norm: 0.03854065015912056
# Total weight diff: 689.394585, Max weight diff: 370.959229
# mse and l0 loss: 2754.2314453125
# R_loss: 0.5292701721191406
# Average R_score: 0.470729798078537
# gradient_norm: 0.029400214552879333
# Total weight diff: 652.612004, Max weight diff: 345.553497
# mse and l0 loss: 2752.4755859375
# R_loss: 0.6055709719657898
# Average R_score: 0.3944290280342102
# gradient_norm: 0.037110064178705215
# Total weight diff: 628.244421, Max weight diff: 327.086609
# mse and l0 loss: 3576.14404296875
# R_loss: 0.4899558424949646
# Average R_score: 0.5100441575050354
# gradient_norm: 0.027147391811013222
# Total weight diff: 672.307944, Max weight diff: 355.381866
# mse and l0 loss: 2775.379150390625
# R_loss: 0.6591274738311768
# Average R_score: 0.34087255597114563
# gradient_norm: 0.03991738334298134
# Total weight diff: 635.671122, Max weight diff: 330.494324
# mse and l0 loss: 2710.91552734375
# R_loss: 0.4936171770095825
# Average R_score: 0.5063828229904175
# gradient_norm: 0.02924528159201145
# Total weight diff: 613.750811, Max weight diff: 315.753845
# mse and l0 loss: 3143.140625
# R_loss: 0.4955463409423828
# Average R_score: 0.5044536590576172
# gradient_norm: 0.027406994253396988
# Total weight diff: 579.261106, Max weight diff: 295.241028
# mse and l0 loss: 2791.2705078125
# R_loss: 0.4768104553222656
# Average R_score: 0.5231895446777344
# gradient_norm: 0.031231222674250603
# Total weight diff: 606.577029, Max weight diff: 323.760925
# mse and l0 loss: 2951.7138671875
# R_loss: 0.42837756872177124
# Average R_score: 0.5716224312782288
# gradient_norm: 0.03320816904306412
# Total weight diff: 597.818720, Max weight diff: 319.428528
# mse and l0 loss: 3000.45751953125
# R_loss: 0.4739282727241516
# Average R_score: 0.5260717272758484
# gradient_norm: 0.024832697585225105
# Total weight diff: 616.876084, Max weight diff: 331.679688
# mse and l0 loss: 4202.63818359375
# R_loss: 0.7156656980514526
# Average R_score: 0.28433430194854736
# gradient_norm: 0.051581062376499176
# Total weight diff: 806.853802, Max weight diff: 452.968140
# mse and l0 loss: 2513.52001953125
# R_loss: 0.7073450088500977
# Average R_score: 0.29265502095222473
# gradient_norm: 0.04550982266664505
# Total weight diff: 771.074932, Max weight diff: 419.891327
# mse and l0 loss: 2922.15576171875
# R_loss: 0.5431338548660278
# Average R_score: 0.45686617493629456
# gradient_norm: 0.030464937910437584
# Total weight diff: 724.589360, Max weight diff: 387.511230
# mse and l0 loss: 2437.803466796875
# R_loss: 0.4071490168571472
# Average R_score: 0.5928509831428528
# gradient_norm: 0.024596355855464935
# Total weight diff: 672.184263, Max weight diff: 351.639771
# mse and l0 loss: 2670.829345703125
# R_loss: 0.7319023609161377
# Average R_score: 0.2680976390838623
# gradient_norm: 0.04810510203242302
# Total weight diff: 655.389415, Max weight diff: 341.209106
# mse and l0 loss: 2683.967041015625
# R_loss: 0.7224693298339844
# Average R_score: 0.27753064036369324
# gradient_norm: 0.04803762957453728
# Total weight diff: 621.317403, Max weight diff: 314.338928
# mse and l0 loss: 2901.50244140625
# R_loss: 0.48481136560440063
# Average R_score: 0.5151886343955994
# gradient_norm: 0.02503848448395729
# Total weight diff: 584.406252, Max weight diff: 292.489471
# mse and l0 loss: 2879.08154296875
# R_loss: 0.515649139881134
# Average R_score: 0.48435086011886597
# gradient_norm: 0.02875594235956669
# Total weight diff: 560.586507, Max weight diff: 282.268372
# mse and l0 loss: 4346.25634765625
# R_loss: 0.7366602420806885
# Average R_score: 0.26333972811698914
# gradient_norm: 0.068813756108284
